# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Vidmizer vs tiktok & youtube
#
# | Learning Rate | Accuracy | Precision 0 | Precision 1 | Recall 0 | Recall 1 | F1 Score 0 | F1 Score 1 | Pfa 0  | Pfa 1  | Pmd 0  | Pmd 1  |
# |---------------|----------|-------------|-------------|----------|----------|------------|------------|--------|--------|--------|--------|
# | 0.1           | 0.8889   | 0.8182      | 1.0         | 1.0      | 0.7778   | 0.9        | 0.875      | 0.1111 | 0.0    | 0.0    | 0.1111 |
# | 0.01          | 0.7222   | 0.6818      | 0.7857      | 0.8333   | 0.6111   | 0.75       | 0.6875     | 0.1944 | 0.0833 | 0.0833 | 0.1944 |
# | 0.001         | 0.5833   | 0.5882      | 0.5789      | 0.5556   | 0.6111   | 0.5714     | 0.5946     | 0.1944 | 0.2222 | 0.2222 | 0.1944 |
# | 0.0001        | 0.5833   | 0.5789      | 0.5882      | 0.6111   | 0.5556   | 0.5946     | 0.5714     | 0.2222 | 0.1944 | 0.1944 | 0.2222 |

# %%
# Définition du style Seaborn pour les graphiques
sns.set(style="whitegrid")

# Données
lrs = ['0.1', '0.01', '0.001', '0.0001']
accuracy = [0.8889, 0.7222, 0.5833, 0.5833]
precision_0 = [0.8182, 0.6818, 0.5882, 0.5789]
precision_1 = [1.0, 0.7857, 0.5789, 0.5882]
recall_0 = [1.0, 0.8333, 0.5556, 0.6111]
recall_1 = [0.7778, 0.6111, 0.6111, 0.5556]
f1_0 = [0.9, 0.75, 0.5714, 0.5946]
f1_1 = [0.875, 0.6875, 0.5946, 0.5714]
pfa_0 = [0.1111, 0.1944, 0.1944, 0.2222]
pfa_1 = [0.0, 0.0833, 0.2222, 0.1944]
pmd_0 = [0.0, 0.0833, 0.2222, 0.1944]
pmd_1 = [0.1111, 0.1944, 0.1944, 0.2222]

# Création des graphiques
fig, ax = plt.subplots(3, 3, figsize=(15, 10))

sns.lineplot(x=lrs, y=accuracy, marker='o', color='b', ax=ax[0, 0])
ax[0, 0].set_title('Accuracy')

sns.lineplot(x=lrs, y=precision_0, marker='o', color='g', ax=ax[0, 1])
ax[0, 1].set_title('Precision Vidmizer')

sns.lineplot(x=lrs, y=precision_1, marker='o', color='r', ax=ax[0, 2])
ax[0, 2].set_title('Precision autre')

sns.lineplot(x=lrs, y=recall_0, marker='o', color='c', ax=ax[1, 0])
ax[1, 0].set_title('Recall Vidmizer')

sns.lineplot(x=lrs, y=recall_1, marker='o', color='m', ax=ax[1, 1])
ax[1, 1].set_title('Recall autre')

sns.lineplot(x=lrs, y=f1_0, marker='o', color='y', ax=ax[1, 2])
ax[1, 2].set_title('F1 score Vidmizer')

sns.lineplot(x=lrs, y=f1_1, marker='o', color='k', ax=ax[2, 0])
ax[2, 0].set_title('F1 score autre')

sns.lineplot(x=lrs, y=pfa_0, marker='o', color='orange', ax=ax[2, 1])
ax[2, 1].set_title('Pfa Vidmizer')

sns.lineplot(x=lrs, y=pfa_1, marker='o', color='purple', ax=ax[2, 2])
ax[2, 2].set_title('Pfa autre')

plt.tight_layout()
plt.show()

# %% [markdown]
# # Tiktok vs vidmizer & youtube
#
# | Learning Rate | Accuracy | Precision 0 | Precision 1 | Recall 0 | Recall 1 | F1 Score 0 | F1 Score 1 | Pfa 0 | Pfa 1 | Pmd 0 | Pmd 1 |
# |---------------|----------|-------------|-------------|----------|----------|------------|------------|-------|-------|-------|-------|
# | 0.1           | 0.9375   | 0.8889      | 1.0         | 1.0      | 0.875    | 0.9412     | 0.9333     | 0.0625| 0.0   | 0.0   | 0.0625|
# | 0.01          | 0.6875   | 0.7143      | 0.6667      | 0.625    | 0.75     | 0.6667     | 0.7059     | 0.125 | 0.1875| 0.1875| 0.125 |
# | 0.001         | 0.625    | 0.6         | 0.6667      | 0.75     | 0.5      | 0.6667     | 0.5714     | 0.25  | 0.125 | 0.125 | 0.25  |
# | 0.0001        | 0.5625   | 0.5385      | 0.6667      | 0.875    | 0.25     | 0.6667     | 0.3636     | 0.375 | 0.0625| 0.0625| 0.375 |

# %%
# Données pour le classificateur TikTok
lr_tiktok = ['0.1', '0.01', '0.001', '0.0001']
accuracy_tiktok = [0.9375, 0.6875, 0.625, 0.5625]
precision_0_tiktok = [0.8889, 0.7143, 0.6, 0.5385]
precision_1_tiktok = [1.0, 0.6667, 0.6667, 0.6667]
recall_0_tiktok = [1.0, 0.625, 0.75, 0.875]
recall_1_tiktok = [0.875, 0.75, 0.5, 0.25]
f1_0_tiktok = [0.9412, 0.6667, 0.6667, 0.6667]
f1_1_tiktok = [0.9333, 0.7059, 0.5714, 0.3636]
pfa_0_tiktok = [0.0625, 0.125, 0.25, 0.375]
pfa_1_tiktok = [0.0, 0.1875, 0.125, 0.0625]
pmd_0_tiktok = [0.0, 0.1875, 0.125, 0.0625]
pmd_1_tiktok = [0.0625, 0.125, 0.25, 0.375]

# Création des graphiques en utilisant Seaborn
fig, ax = plt.subplots(3, 3, figsize=(15, 10))

sns.lineplot(x=lr_tiktok, y=accuracy_tiktok, marker='o', color='b', ax=ax[0, 0])
ax[0, 0].set_title('Accuracy TikTok')

sns.lineplot(x=lr_tiktok, y=precision_0_tiktok, marker='o', color='g', ax=ax[0, 1])
ax[0, 1].set_title('Precision TikTok')

sns.lineplot(x=lr_tiktok, y=precision_1_tiktok, marker='o', color='r', ax=ax[0, 2])
ax[0, 2].set_title('Precision autre')

sns.lineplot(x=lr_tiktok, y=recall_0_tiktok, marker='o', color='c', ax=ax[1, 0])
ax[1, 0].set_title('Recall TikTok')

sns.lineplot(x=lr_tiktok, y=recall_1_tiktok, marker='o', color='m', ax=ax[1, 1])
ax[1, 1].set_title('Recall autre')

sns.lineplot(x=lr_tiktok, y=f1_0_tiktok, marker='o', color='y', ax=ax[1, 2])
ax[1, 2].set_title('F1 score TikTok')

sns.lineplot(x=lr_tiktok, y=f1_1_tiktok, marker='o', color='k', ax=ax[2, 0])
ax[2, 0].set_title('F1 score autre')

sns.lineplot(x=lr_tiktok, y=pfa_0_tiktok, marker='o', color='orange', ax=ax[2, 1])
ax[2, 1].set_title('Pfa TikTok')

sns.lineplot(x=lr_tiktok, y=pfa_1_tiktok, marker='o', color='purple', ax=ax[2, 2])
ax[2, 2].set_title('Pfa autre')

plt.tight_layout()
plt.show()

# %% [markdown]
# # Youtube vs vidmizer & tiktok
# | Learning Rate | Accuracy | Precision 0 | Precision 1 | Recall 0 | Recall 1 | F1 Score 0 | F1 Score 1 | Pfa 0  | Pfa 1  | Pmd 0  | Pmd 1  |
# |---------------|----------|-------------|-------------|----------|----------|------------|------------|--------|--------|--------|--------|
# | 0.01          | 0.8      | 0.7143      | 1.0         | 1.0      | 0.6      | 0.8333     | 0.75       | 0.2    | 0.0    | 0.0    | 0.2    |
# | 0.001         | 0.6      | 0.5714      | 0.6667      | 0.8      | 0.4      | 0.6667     | 0.5        | 0.3    | 0.1    | 0.1    | 0.3    |
# | 0.001         | 0.55     | 0.5455      | 0.5556      | 0.6      | 0.5      | 0.5714     | 0.5263     | 0.25   | 0.2    | 0.2    | 0.25   |
# | 0.0001        | 0.6      | 0.6         | 0.6         | 0.6      | 0.6      | 0.6        | 0.6        | 0.2    | 0.2    | 0.2    | 0.2    |

# %%
# Données pour le classificateur YouTube
lr_youtube = ['0.1', '0.01', '0.001', '0.0001']
accuracy_youtube = [0.8, 0.6, 0.55, 0.6]
precision_0_youtube = [0.7143, 0.5714, 0.5455, 0.6]
precision_1_youtube = [1.0, 0.6667, 0.5556, 0.6]
recall_0_youtube = [1.0, 0.8, 0.6, 0.6]
recall_1_youtube = [0.6, 0.4, 0.5, 0.6]
f1_0_youtube = [0.8333, 0.6667, 0.5714, 0.6]
f1_1_youtube = [0.75, 0.5, 0.5263, 0.6]
pfa_0_youtube = [0.2, 0.3, 0.25, 0.2]
pfa_1_youtube = [0.0, 0.1, 0.2, 0.2]
pmd_0_youtube = [0.0, 0.1, 0.2, 0.2]
pmd_1_youtube = [0.2, 0.3, 0.25, 0.2]

# Création des graphiques en utilisant Seaborn
fig, ax = plt.subplots(3, 3, figsize=(15, 10))

sns.lineplot(x=lr_youtube, y=accuracy_youtube, marker='o', color='b', ax=ax[0, 0])
ax[0, 0].set_title('Accuracy YouTube')

sns.lineplot(x=lr_youtube, y=precision_0_youtube, marker='o', color='g', ax=ax[0, 1])
ax[0, 1].set_title('Precision YouTube')

sns.lineplot(x=lr_youtube, y=precision_1_youtube, marker='o', color='r', ax=ax[0, 2])
ax[0, 2].set_title('Precision autre')

sns.lineplot(x=lr_youtube, y=recall_0_youtube, marker='o', color='c', ax=ax[1, 0])
ax[1, 0].set_title('Recall YouTube')

sns.lineplot(x=lr_youtube, y=recall_1_youtube, marker='o', color='m', ax=ax[1, 1])
ax[1, 1].set_title('Recall autre')

sns.lineplot(x=lr_youtube, y=f1_0_youtube, marker='o', color='y', ax=ax[1, 2])
ax[1, 2].set_title('F1 score YouTube')

sns.lineplot(x=lr_youtube, y=f1_1_youtube, marker='o', color='k', ax=ax[2, 0])
ax[2, 0].set_title('F1 score autre')

sns.lineplot(x=lr_youtube, y=pfa_0_youtube, marker='o', color='orange', ax=ax[2, 1])
ax[2, 1].set_title('Pfa YouTube')

sns.lineplot(x=lr_youtube, y=pfa_1_youtube, marker='o', color='purple', ax=ax[2, 2])
ax[2, 2].set_title('Pfa autre')

plt.tight_layout()
plt.show()

# %% [markdown]
# # Casacades metrics

# %%
v_t_y = [(0, 3, [0.6453651785850525]),
(2, 3, [0.9909548163414001, 0.9888908863067627, 0.7976873517036438]),
(2, 3, [0.7463315725326538, 0.9443224668502808, 0.7636215686798096]),
(2, 3, [0.7277541756629944, 0.6961020827293396, 0.7573810815811157]),
(2, 3, [0.5807727575302124, 0.5201466083526611, 0.7778492569923401]),
(1, 3, [1.0, 0.9999972581863403]),
(1, 3, [1.0, 0.9999992847442627]),
(1, 3, [1.0, 0.9999409914016724]),
(0, 1, [0.6453651785850525]),
(1, 1, [1.0, 0.9999998807907104]),
(0, 1, [0.5049631595611572]),
(1, 1, [1.0, 0.9999995231628418]),
(1, 1, [0.9957543611526489, 0.9986931681632996]),
(1, 1, [0.998914361000061, 0.9662871956825256]),
(1, 1, [1.0, 0.999998927116394]),
(1, 1, [1.0, 0.9998743534088135]),
(0, 0, [0.9966105818748474]),
(0, 0, [0.6238546371459961]),
(0, 0, [0.6027296781539917]),
(0, 0, [0.9981591105461121]),
(0, 0, [0.9610527753829956]),
(0, 0, [0.919207751750946]),
(0, 0, [0.973599374294281]),
(0, 0, [0.6122866868972778]),
(2, 2, [0.9497188329696655, 0.994707465171814, 0.7415632605552673]),
(0, 2, [0.6365941762924194]),
(2, 2, [0.5437545776367188, 0.7422865033149719, 0.7510762810707092]),
(2, 2, [0.5700851678848267, 0.5481172204017639, 0.7778434157371521]),
(2, 2, [0.5457105040550232, 0.5400242805480957, 0.7733374834060669]),
(2, 2, [0.9992843270301819, 0.9813464283943176, 0.9774653911590576]),
(2, 2, [0.9994744658470154, 0.991202712059021, 0.9694845080375671]),
(2, 2, [0.9995276927947998, 0.9950129389762878, 0.9773023128509521])]

v_y_t = [(0, 3, [0.6453651785850525]),
(2, 3, [0.9909548163414001, 0.7976873517036438]),
(2, 3, [0.7463315725326538, 0.7636215686798096]),
(2, 3, [0.7277541756629944, 0.7573810815811157]),
(2, 3, [0.5807727575302124, 0.7778492569923401]),
(1, 3, [1.0, 0.8890114426612854, 0.9999972581863403]),
(1, 3, [1.0, 0.9645259976387024, 0.9999992847442627]),
(2, 3, [1.0, 0.9561905264854431]),
(0, 1, [0.6453651785850525]),
(1, 1, [1.0, 0.9999953508377075, 0.9999998807907104]),
(0, 1, [0.5049631595611572]),
(1, 1, [1.0, 0.9999892711639404, 0.9999995231628418]),
(1, 1, [0.9957543611526489, 0.9616971015930176, 0.9986931681632996]),
(1, 1, [0.998914361000061, 0.803416907787323, 0.9662871956825256]),
(1, 1, [1.0, 0.9260817766189575, 0.999998927116394]),
(2, 1, [1.0, 0.9678329825401306]),
(0, 0, [0.9966105818748474]),
(0, 0, [0.6238546371459961]),
(0, 0, [0.6027296781539917]),
(0, 0, [0.9981591105461121]),
(0, 0, [0.9610527753829956]),
(0, 0, [0.919207751750946]),
(0, 0, [0.973599374294281]),
(0, 0, [0.6122866868972778]),
(2, 2, [0.9497188329696655, 0.7415632605552673]),
(0, 2, [0.6365941762924194]),
(2, 2, [0.5437545776367188, 0.7510762810707092]),
(2, 2, [0.5700851678848267, 0.7778434157371521]),
(2, 2, [0.5457105040550232, 0.7733374834060669]),
(2, 2, [0.9992843270301819, 0.9774653911590576]),
(2, 2, [0.9994744658470154, 0.9694845080375671]),
(2, 2, [0.9995276927947998, 0.9773023128509521])]

t_v_y = [(1, 3, [0.6034185886383057]),
(2, 3, [0.9888908863067627, 0.9909548163414001, 0.7976873517036438]),
(2, 3, [0.9443224668502808, 0.7463315725326538, 0.7636215686798096]),
(2, 3, [0.6961020827293396, 0.7277541756629944, 0.7573810815811157]),
(2, 3, [0.5201466083526611, 0.5807728171348572, 0.7778492569923401]),
(1, 3, [0.9999972581863403]),
(1, 3, [0.9999992847442627]),
(1, 3, [0.9999409914016724]),
(1, 1, [0.6034185886383057]),
(1, 1, [0.9999998807907104]),
(1, 1, [0.947433352470398]),
(1, 1, [0.9999995231628418]),
(1, 1, [0.9986931681632996]),
(1, 1, [0.9662871956825256]),
(1, 1, [0.999998927116394]),
(1, 1, [0.9998743534088135]),
(0, 0, [0.9992467164993286, 0.9966105818748474]),
(0, 0, [0.8785927891731262, 0.6238546371459961]),
(0, 0, [0.9276040196418762, 0.6027296185493469]),
(0, 0, [0.9994480013847351, 0.9981591105461121]),
(0, 0, [0.9985465407371521, 0.9610527753829956]),
(0, 0, [0.9984725117683411, 0.919207751750946]),
(0, 0, [0.998749852180481, 0.973599374294281]),
(0, 0, [0.9921765923500061, 0.6122866868972778]),
(2, 2, [0.994707465171814, 0.9497188329696655, 0.7415632605552673]),
(1, 2, [0.5108287334442139]),
(2, 2, [0.7422865033149719, 0.5437545776367188, 0.7510762810707092]),
(2, 2, [0.5481172204017639, 0.5700851678848267, 0.7778434157371521]),
(2, 2, [0.5400242805480957, 0.5457105040550232, 0.7733374834060669]),
(2, 2, [0.9813464283943176, 0.9992843270301819, 0.9774653911590576]),
(2, 2, [0.991202712059021, 0.9994744658470154, 0.9694845080375671]),
(2, 2, [0.9950129389762878, 0.9995276927947998, 0.9773023128509521])]

t_y_v = [(1, 3, [0.6034185886383057]),
(2, 3, [0.9888908863067627, 0.7976873517036438]),
(2, 3, [0.9443224668502808, 0.7636215686798096]),
(2, 3, [0.6961020827293396, 0.7573810815811157]),
(2, 3, [0.5201466083526611, 0.7778492569923401]),
(1, 3, [0.9999972581863403]),
(1, 3, [0.9999992847442627]),
(1, 3, [0.9999409914016724]),
(1, 1, [0.6034185886383057]),
(1, 1, [0.9999998807907104]),
(1, 1, [0.947433352470398]),
(1, 1, [0.9999995231628418]),
(1, 1, [0.9986931681632996]),
(1, 1, [0.9662871956825256]),
(1, 1, [0.999998927116394]),
(1, 1, [0.9998743534088135]),
(0, 0, [0.9992467164993286, 0.885845422744751, 0.9966105818748474]),
(2, 0, [0.8785927891731262, 0.7301041483879089]),
(2, 0, [0.9276040196418762, 0.7158656120300293]),
(0, 0, [0.9994480013847351, 0.9040367007255554, 0.9981591105461121]),
(0, 0, [0.9985465407371521, 0.5214872360229492, 0.9610527753829956]),
(0, 0, [0.9984725117683411, 0.5213239192962646, 0.919207751750946]),
(0, 0, [0.998749852180481, 0.6343775391578674, 0.973599374294281]),
(2, 0, [0.9921765923500061, 0.5110204815864563]),
(2, 2, [0.994707465171814, 0.7415632605552673]),
(1, 2, [0.5108287334442139]),
(2, 2, [0.7422865033149719, 0.7510762810707092]),
(2, 2, [0.5481172204017639, 0.7778434157371521]),
(2, 2, [0.5400242805480957, 0.7733374834060669]),
(2, 2, [0.9813464283943176, 0.9774653911590576]),
(2, 2, [0.991202712059021, 0.9694845080375671]),
(2, 2, [0.9950129389762878, 0.9773023128509521])]

y_v_t = [(2, 3, [0.7717554569244385]),
(2, 3, [0.7976873517036438]),
(2, 3, [0.7636215686798096]),
(2, 3, [0.7573810815811157]),
(2, 3, [0.7778492569923401]),
(1, 3, [0.889011561870575, 1.0, 0.9999972581863403]),
(1, 3, [0.9645259976387024, 1.0, 0.9999992847442627]),
(2, 3, [0.9561905264854431]),
(2, 1, [0.7717554569244385]),
(1, 1, [0.9999953508377075, 1.0, 0.9999998807907104]),
(2, 1, [0.6605082154273987]),
(1, 1, [0.9999892711639404, 1.0, 0.9999995231628418]),
(1, 1, [0.9616971015930176, 0.9957543611526489, 0.9986931681632996]),
(1, 1, [0.803416907787323, 0.998914361000061, 0.9662871956825256]),
(1, 1, [0.9260817766189575, 1.0, 0.999998927116394]),
(2, 1, [0.9678329825401306]),
(0, 0, [0.8858455419540405, 0.9966105818748474]),
(2, 0, [0.7301041483879089]),
(2, 0, [0.7158656120300293]),
(0, 0, [0.9040367007255554, 0.9981591105461121]),
(0, 0, [0.5214871764183044, 0.9610527753829956]),
(0, 0, [0.5213239192962646, 0.919207751750946]),
(0, 0, [0.6343775391578674, 0.973599374294281]),
(2, 0, [0.5110204219818115]),
(2, 2, [0.7415632605552673]),
(2, 2, [0.7669408321380615]),
(2, 2, [0.7510762810707092]),
(2, 2, [0.7778434157371521]),
(2, 2, [0.7733374834060669]),
(2, 2, [0.9774653911590576]),
(2, 2, [0.9694845080375671]),
(2, 2, [0.9773023128509521])]

y_t_v = [(2, 3, [0.7717554569244385]),
(2, 3, [0.7976873517036438]),
(2, 3, [0.7636215686798096]),
(2, 3, [0.7573810815811157]),
(2, 3, [0.7778492569923401]),
(1, 3, [0.889011561870575, 0.9999972581863403]),
(1, 3, [0.9645259976387024, 0.9999992847442627]),
(2, 3, [0.9561905264854431]),
(2, 1, [0.7717554569244385]),
(1, 1, [0.9999953508377075, 0.9999998807907104]),
(2, 1, [0.6605082154273987]),
(1, 1, [0.9999892711639404, 0.9999995231628418]),
(1, 1, [0.9616971015930176, 0.9986931681632996]),
(1, 1, [0.803416907787323, 0.9662871956825256]),
(1, 1, [0.9260817766189575, 0.999998927116394]),
(2, 1, [0.9678329825401306]),
(0, 0, [0.8858455419540405, 0.9992467164993286, 0.9966105818748474]),
(2, 0, [0.7301041483879089]),
(2, 0, [0.7158656120300293]),
(0, 0, [0.9040367007255554, 0.9994480013847351, 0.9981591105461121]),
(0, 0, [0.5214871764183044, 0.9985465407371521, 0.9610527753829956]),
(0, 0, [0.5213239192962646, 0.9984725117683411, 0.919207751750946]),
(0, 0, [0.6343775391578674, 0.998749852180481, 0.973599374294281]),
(2, 0, [0.5110204219818115]),
(2, 2, [0.7415632605552673]),
(2, 2, [0.7669408321380615]),
(2, 2, [0.7510762810707092]),
(2, 2, [0.7778434157371521]),
(2, 2, [0.7733374834060669]),
(2, 2, [0.9774653911590576]),
(2, 2, [0.9694845080375671]),
(2, 2, [0.9773023128509521])]

cascades = [v_t_y, v_y_t, t_v_y, t_y_v, y_v_t, y_t_v]
titles = ['Vidmizer -> TikTok -> YouTube', 'Vidmizer -> YouTube -> TikTok', 'TikTok -> Vidmizer -> YouTube', 'TikTok -> YouTube -> Vidmizer', 'YouTube -> Vidmizer -> TikTok', 'YouTube -> TikTok -> Vidmizer']

# %%
import matplotlib.pyplot as plt
import numpy as np

plt.figure(figsize=(20, 16))
for i, (eval_labels, title) in enumerate(zip(cascades, titles)):
    # Calculer le nombre de prédictions correctes et incorrectes pour chaque classe prédite
    pred_counts = {0: {'correct': 0, 'incorrect': 0},
                   1: {'correct': 0, 'incorrect': 0},
                   2: {'correct': 0, 'incorrect': 0},
                   3: {'correct': 0, 'incorrect': 0}}

    for pred, truth, _ in eval_labels:
        if pred == truth:
            pred_counts[pred]['correct'] += 1
        else:
            pred_counts[pred]['incorrect'] += 1

    # Préparation des données pour le bar chart
    classes = ['Vidmizer', 'TikTok', 'YouTube', 'Meta']
    correct_counts = [pred_counts[i]['correct'] for i in range(4)]
    incorrect_counts = [pred_counts[i]['incorrect'] for i in range(4)]

    bar_width = 0.35
    index = np.arange(len(classes))

    # Création du bar chart
    plt.subplot(2, 3, i + 1)
    bar1 = plt.bar(index, correct_counts, bar_width, color='b', label='Correct')
    bar2 = plt.bar(index + bar_width, incorrect_counts, bar_width, color='r', label='Incorrect')

    plt.xlabel('Classes')
    plt.ylabel('Nombre de Prédictions')
    plt.title(f'Nombre de Prédictions pour {title}')
    plt.xticks(index + bar_width / 2, classes)
    plt.legend()
    plt.tight_layout()

# %%
for i, (eval_labels, title) in enumerate(zip(cascades, titles)):
    correct = 0
    rien = 0
    total = 0
    mal_predit = 0

    for duo_compare in eval_labels:
        total += 1
        if duo_compare[0] == duo_compare[1]:
            correct += 1
        elif duo_compare[0] == 3:
            rien += 1
        else:
            mal_predit += 1

    print(f'========Cascade {title}========')
    print('Accuracy des classifiers en Cascade :', correct / total)
    print('Nombre de Meta classifiés :', rien)
    print('Nombre de mal prédits :', mal_predit)
    print('=====================================================')
    print()
# Out:
# ========Cascade Vidmizer -> TikTok -> YouTube========
# Accuracy des classifiers en Cascade : 0.65625
# Nombre de Meta classifiés : 0
# Nombre de mal prédits : 11
# ...
#
# ========Cascade Vidmizer -> YouTube -> TikTok========
# Accuracy des classifiers en Cascade : 0.625
# Nombre de Meta classifiés : 0
# Nombre de mal prédits : 12
# ...
#
# ========Cascade TikTok -> Vidmizer -> YouTube========
# Accuracy des classifiers en Cascade : 0.71875
# Nombre de Meta classifiés : 0
# Nombre de mal prédits : 9
# ...
#
# ========Cascade TikTok -> YouTube -> Vidmizer========
# Accuracy des classifiers en Cascade : 0.625
# Nombre de Meta classifiés : 0
# Nombre de mal prédits : 12
# ...
#
# ========Cascade YouTube -> Vidmizer -> TikTok========
# Accuracy des classifiers en Cascade : 0.5625
# Nombre de Meta classifiés : 0
# Nombre de mal prédits : 14
# ...
#
# ========Cascade YouTube -> TikTok -> Vidmizer========
# Accuracy des classifiers en Cascade : 0.5625
# Nombre de Meta classifiés : 0
# Nombre de mal prédits : 14
# ...
