# %% [markdown]
# # DataLoader
# <p> Tutorial link: https://github.com/RaivoKoot/Video-Dataset-Loading-Pytorch or https://video-dataset-loading-pytorch.readthedocs.io/en/latest/ </p>

# %% [markdown]
# ## Database preparation
# <li> Input : 3 folders named ( tiktok, youtube, vimizer) which contains the mp4 videos  </li>
# <li> For each Folders : Create an homologue folder which contains num_videos folders. All of these folders named by the index of the video contain each frames of the same video. </li>
# <li> Annotations.txt file generation </li>

# %% [markdown]
# ### Creation of the architecture

# %%
### Useful Path ###
dataset_video= 'dataset_video'
dataset = 'dataset'

# %%
##### Librairies #####
import os
import cv2
import subprocess
import shutil

# %%
### Nettoyer la base de donnée ######
# remove all the folder of the database
shutil.rmtree(dataset)

# %%
####### Database creation ########
os.makedirs(dataset)
classe=-1

for folder in os.listdir(dataset_video):

    classe=classe+1

    folder_path = dataset + '/'+ folder
    os.makedirs(folder_path)
    print('creation of the folder ' + folder)
    
    folder_video_path = dataset_video + '/'+ folder

    for i, video in  enumerate(os.listdir(folder_video_path)) :

        video_path = folder_video_path + '/' + video
        output_folder_video_path = folder_path + '/' + str(i)

        # Creation of the frame folder for the video i 
        os.makedirs(output_folder_video_path)

        # Extraction of the frames in this folder
        command = "ffmpeg -i " + video_path + " -vf fps=2 " + output_folder_video_path +"/img_%05d.png"
        subprocess.run(command, shell=True)

        #Ajout de la ligne dans annotation.txt
        elements = os.listdir(output_folder_video_path)
        compteur= len(elements)
       

        with open('annotation.txt', 'a') as file:
            file.write(folder + '/' + str(i)+ " 1 " + str(compteur) + " " + str(classe) + "\n")
# Out:
# creation of the folder vimizer
# ffmpeg version 6.0 Copyright (c) 2000-2023 the FFmpeg developers
#   built with Apple clang version 15.0.0 (clang-1500.0.40.1)
#   configuration: --prefix=/opt/homebrew/Cellar/ffmpeg/6.0_1 --enable-shared --enable-pthreads --enable-version3 --cc=clang --host-cflags= --host-ldflags='-Wl,-ld_classic' --enable-ffplay --enable-gnutls --enable-gpl --enable-libaom --enable-libaribb24 --enable-libbluray --enable-libdav1d --enable-libjxl --enable-libmp3lame --enable-libopus --enable-librav1e --enable-librist --enable-librubberband --enable-libsnappy --enable-libsrt --enable-libsvtav1 --enable-libtesseract --enable-libtheora --enable-libvidstab --enable-libvmaf --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxml2 --enable-libxvid --enable-lzma --enable-libfontconfig --enable-libfreetype --enable-frei0r --enable-libass --enable-libopencore-amrnb --enable-libopencore-amrwb --enable-libopenjpeg --enable-libspeex --enable-libsoxr --enable-libzmq --enable-libzimg --disable-libjack --disable-indev=jack --enable-videotoolbox --enable-audiotoolbox --enable-neon
#   libavutil      58.  2.100 / 58.  2.100
#   libavcodec     60.  3.100 / 60.  3.100
#   libavformat    60.  3.100 / 60.  3.100
#   libavdevice    60.  1.100 / 60.  1.100
#   libavfilter     9.  3.100 /  9.  3.100
#   libswscale      7.  1.100 /  7.  1.100
#   libswresample   4. 10.100 /  4. 10.100
#   libpostproc    57.  1.100 / 57.  1.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from 'dataset_video/vimizer/7.mp4':
#   Metadata:
#     major_brand     : mp42
#     minor_version   : 0
#     compatible_brands: mp42mp41
#     creation_time   : 2023-04-12T09:04:07.000000Z
#   Duration: 00:00:20.00, start: 0.000000, bitrate: 9569 kb/s
#   Stream #0:0[0x1](eng): Video: h264 (High) (avc1 / 0x31637661), yuv420p(tv, bt709, progressive), 1920x1080 [SAR 1:1 DAR 16:9], 9226 kb/s, 25 fps, 25 tbr, 25k tbn (default)
#     Metadata:
#       creation_time   : 2023-04-12T09:04:07.000000Z
#       handler_name    : ?Mainconcept Video Media Handler
#       vendor_id       : [0][0][0][0]
#       encoder         : AVC Coding
#   Stream #0:1[0x2](eng): Audio: aac (LC) (mp4a / 0x6134706D), 48000 Hz, stereo, fltp, 317 kb/s (default)
#     Metadata:
#       creation_time   : 2023-04-12T09:04:07.000000Z
#       handler_name    : #Mainconcept MP4 Sound Media Handler
#       vendor_id       : [0][0][0][0]
# Stream mapping:
#   Stream #0:0 -> #0:0 (h264 (native) -> png (native))
# Press [q] to stop, [?] for help
# [swscaler @ 0x138690000] [swscaler @ 0x159818000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x138690000] [swscaler @ 0x159828000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x138690000] [swscaler @ 0x159838000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x138690000] [swscaler @ 0x159848000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x138690000] [swscaler @ 0x159858000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x138690000] [swscaler @ 0x159868000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x138690000] [swscaler @ 0x159878000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x138690000] [swscaler @ 0x159888000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x138690000] [swscaler @ 0x159898000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x108060000] [swscaler @ 0x138690000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x108060000] [swscaler @ 0x1389f8000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x108060000] [swscaler @ 0x138a10000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x108060000] [swscaler @ 0x138a20000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x108060000] [swscaler @ 0x138a30000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x108060000] [swscaler @ 0x138a40000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x108060000] [swscaler @ 0x138a50000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x108060000] [swscaler @ 0x138a60000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x108060000] [swscaler @ 0x138a70000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x138a70000] [swscaler @ 0x160008000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x138a70000] [swscaler @ 0x148eb8000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x138a70000] [swscaler @ 0x1480a8000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x138a70000] [swscaler @ 0x1480b8000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x138a70000] [swscaler @ 0x1480c8000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x138a70000] [swscaler @ 0x1493c8000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x138a70000] [swscaler @ 0x1493d8000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x138a70000] [swscaler @ 0x1493e8000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x138a70000] [swscaler @ 0x1493f8000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x140f90000] [swscaler @ 0x108060000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x140f90000] [swscaler @ 0x108070000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x140f90000] [swscaler @ 0x118070000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x140f90000] [swscaler @ 0x118080000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x140f90000] [swscaler @ 0x118090000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x140f90000] [swscaler @ 0x140fa0000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x140f90000] [swscaler @ 0x140fb0000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x140f90000] [swscaler @ 0x140fc0000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x140f90000] [swscaler @ 0x140fd0000] No accelerated colorspace conversion found from yuv420p to rgb24.
# Output #0, image2, to 'dataset/vimizer/0/img_%05d.png':
#   Metadata:
#     major_brand     : mp42
#     minor_version   : 0
#     compatible_brands: mp42mp41
#     encoder         : Lavf60.3.100
#   Stream #0:0(eng): Video: png, rgb24(pc, gbr/bt709/bt709, progressive), 1920x1080 [SAR 1:1 DAR 16:9], q=2-31, 200 kb/s, 2 fps, 2 tbn (default)
#     Metadata:
#       creation_time   : 2023-04-12T09:04:07.000000Z
#       handler_name    : ?Mainconcept Video Media Handler
#       vendor_id       : [0][0][0][0]
#       encoder         : Lavc60.3.100 png
# frame=   40 fps= 15 q=-0.0 Lsize=N/A time=00:00:19.50 bitrate=N/A speed=7.23x    ts/s speed=N/A
# video:84977kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: unknown
# ffmpeg version 6.0 Copyright (c) 2000-2023 the FFmpeg developers
#   built with Apple clang version 15.0.0 (clang-1500.0.40.1)
#   configuration: --prefix=/opt/homebrew/Cellar/ffmpeg/6.0_1 --enable-shared --enable-pthreads --enable-version3 --cc=clang --host-cflags= --host-ldflags='-Wl,-ld_classic' --enable-ffplay --enable-gnutls --enable-gpl --enable-libaom --enable-libaribb24 --enable-libbluray --enable-libdav1d --enable-libjxl --enable-libmp3lame --enable-libopus --enable-librav1e --enable-librist --enable-librubberband --enable-libsnappy --enable-libsrt --enable-libsvtav1 --enable-libtesseract --enable-libtheora --enable-libvidstab --enable-libvmaf --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxml2 --enable-libxvid --enable-lzma --enable-libfontconfig --enable-libfreetype --enable-frei0r --enable-libass --enable-libopencore-amrnb --enable-libopencore-amrwb --enable-libopenjpeg --enable-libspeex --enable-libsoxr --enable-libzmq --enable-libzimg --disable-libjack --disable-indev=jack --enable-videotoolbox --enable-audiotoolbox --enable-neon
#   libavutil      58.  2.100 / 58.  2.100
#   libavcodec     60.  3.100 / 60.  3.100
#   libavformat    60.  3.100 / 60.  3.100
#   libavdevice    60.  1.100 / 60.  1.100
#   libavfilter     9.  3.100 /  9.  3.100
#   libswscale      7.  1.100 /  7.  1.100
#   libswresample   4. 10.100 /  4. 10.100
#   libpostproc    57.  1.100 / 57.  1.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from 'dataset_video/vimizer/6.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf60.3.100
#     comment         : Create videos with https://clipchamp.com/en/video-editor - free online video editor, video compressor, video converter.
#   Duration: 00:00:53.07, start: 0.000000, bitrate: 3604 kb/s
#   Stream #0:0[0x1](und): Video: h264 (High) (avc1 / 0x31637661), yuv420p(progressive), 1920x1080 [SAR 1:1 DAR 16:9], 3479 kb/s, 30 fps, 30 tbr, 15360 tbn (default)
#     Metadata:
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
#       encoder         : Lavc60.3.100 libx264
#   Stream #0:1[0x2](und): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 128 kb/s (default)
#     Metadata:
#       handler_name    : SoundHandler
#       vendor_id       : [0][0][0][0]
# Stream mapping:
#   Stream #0:0 -> #0:0 (h264 (native) -> png (native))
# Press [q] to stop, [?] for help
# [swscaler @ 0x158018000] [swscaler @ 0x150280000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x158018000] [swscaler @ 0x150290000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x158018000] [swscaler @ 0x1502a0000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x158018000] [swscaler @ 0x1502b0000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x158018000] [swscaler @ 0x1502c0000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x158018000] [swscaler @ 0x1502d0000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x158018000] [swscaler @ 0x1502e0000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x158018000] [swscaler @ 0x1502f0000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x158018000] [swscaler @ 0x150300000] No accelerated colorspace conversion found from yuv420p to rgb24.
# Output #0, image2, to 'dataset/vimizer/1/img_%05d.png':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     comment         : Create videos with https://clipchamp.com/en/video-editor - free online video editor, video compressor, video converter.
#     encoder         : Lavf60.3.100
#   Stream #0:0(und): Video: png, rgb24(pc, gbr/unknown/unknown, progressive), 1920x1080 [SAR 1:1 DAR 16:9], q=2-31, 200 kb/s, 2 fps, 2 tbn (default)
#     Metadata:
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
#       encoder         : Lavc60.3.100 png
# frame=  106 fps= 15 q=-0.0 Lsize=N/A time=00:00:52.50 bitrate=N/A speed=7.19x    ts/s speed=N/A
# video:292255kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: unknown
# ffmpeg version 6.0 Copyright (c) 2000-2023 the FFmpeg developers
#   built with Apple clang version 15.0.0 (clang-1500.0.40.1)
#   configuration: --prefix=/opt/homebrew/Cellar/ffmpeg/6.0_1 --enable-shared --enable-pthreads --enable-version3 --cc=clang --host-cflags= --host-ldflags='-Wl,-ld_classic' --enable-ffplay --enable-gnutls --enable-gpl --enable-libaom --enable-libaribb24 --enable-libbluray --enable-libdav1d --enable-libjxl --enable-libmp3lame --enable-libopus --enable-librav1e --enable-librist --enable-librubberband --enable-libsnappy --enable-libsrt --enable-libsvtav1 --enable-libtesseract --enable-libtheora --enable-libvidstab --enable-libvmaf --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxml2 --enable-libxvid --enable-lzma --enable-libfontconfig --enable-libfreetype --enable-frei0r --enable-libass --enable-libopencore-amrnb --enable-libopencore-amrwb --enable-libopenjpeg --enable-libspeex --enable-libsoxr --enable-libzmq --enable-libzimg --disable-libjack --disable-indev=jack --enable-videotoolbox --enable-audiotoolbox --enable-neon
#   libavutil      58.  2.100 / 58.  2.100
#   libavcodec     60.  3.100 / 60.  3.100
#   libavformat    60.  3.100 / 60.  3.100
#   libavdevice    60.  1.100 / 60.  1.100
#   libavfilter     9.  3.100 /  9.  3.100
#   libswscale      7.  1.100 /  7.  1.100
#   libswresample   4. 10.100 /  4. 10.100
#   libpostproc    57.  1.100 / 57.  1.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from 'dataset_video/vimizer/4.mp4':
#   Metadata:
#     major_brand     : mp42
#     minor_version   : 0
#     compatible_brands: mp42mp41
#     creation_time   : 2023-07-03T15:18:23.000000Z
#   Duration: 00:00:20.00, start: 0.000000, bitrate: 9564 kb/s
#   Stream #0:0[0x1](eng): Video: h264 (Main) (avc1 / 0x31637661), yuv420p(tv, bt709, progressive), 1920x1080 [SAR 1:1 DAR 16:9], 9202 kb/s, 25 fps, 25 tbr, 25k tbn (default)
#     Metadata:
#       creation_time   : 2023-07-03T15:18:23.000000Z
#       handler_name    : ?Mainconcept Video Media Handler
#       vendor_id       : [0][0][0][0]
#       encoder         : AVC Coding
#   Stream #0:1[0x2](eng): Audio: aac (LC) (mp4a / 0x6134706D), 48000 Hz, stereo, fltp, 317 kb/s (default)
#     Metadata:
#       creation_time   : 2023-07-03T15:18:27.000000Z
#       handler_name    : #Mainconcept MP4 Sound Media Handler
#       vendor_id       : [0][0][0][0]
# Stream mapping:
#   Stream #0:0 -> #0:0 (h264 (native) -> png (native))
# Press [q] to stop, [?] for help
# [swscaler @ 0x1585f8000] [swscaler @ 0x140360000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x1585f8000] [swscaler @ 0x140370000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x1585f8000] [swscaler @ 0x160008000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x1585f8000] [swscaler @ 0x160018000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x1585f8000] [swscaler @ 0x160028000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x1585f8000] [swscaler @ 0x160038000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x1585f8000] [swscaler @ 0x160048000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x1585f8000] [swscaler @ 0x160058000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x1585f8000] [swscaler @ 0x160068000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x128880000] [swscaler @ 0x160068000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x128880000] [swscaler @ 0x160008000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x128880000] [swscaler @ 0x160018000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x128880000] [swscaler @ 0x160028000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x128880000] [swscaler @ 0x160038000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x128880000] [swscaler @ 0x160048000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x128880000] [swscaler @ 0x160058000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x128880000] [swscaler @ 0x160200000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x128880000] [swscaler @ 0x160210000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x160210000] [swscaler @ 0x118ad0000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x160210000] [swscaler @ 0x118ae0000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x160210000] [swscaler @ 0x118af0000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x160210000] [swscaler @ 0x118b00000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x160210000] [swscaler @ 0x118b10000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x160210000] [swscaler @ 0x118b20000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x160210000] [swscaler @ 0x118b30000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x160210000] [swscaler @ 0x118b40000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x160210000] [swscaler @ 0x118b50000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x118b50000] [swscaler @ 0x160210000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x118b50000] [swscaler @ 0x160200000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x118b50000] [swscaler @ 0x160008000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x118b50000] [swscaler @ 0x160018000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x118b50000] [swscaler @ 0x160028000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x118b50000] [swscaler @ 0x160038000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x118b50000] [swscaler @ 0x160048000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x118b50000] [swscaler @ 0x160058000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x118b50000] [swscaler @ 0x160068000] No accelerated colorspace conversion found from yuv420p to rgb24.
# Output #0, image2, to 'dataset/vimizer/2/img_%05d.png':
#   Metadata:
#     major_brand     : mp42
#     minor_version   : 0
#     compatible_brands: mp42mp41
#     encoder         : Lavf60.3.100
#   Stream #0:0(eng): Video: png, rgb24(pc, gbr/bt709/bt709, progressive), 1920x1080 [SAR 1:1 DAR 16:9], q=2-31, 200 kb/s, 2 fps, 2 tbn (default)
#     Metadata:
#       creation_time   : 2023-07-03T15:18:23.000000Z
#       handler_name    : ?Mainconcept Video Media Handler
#       vendor_id       : [0][0][0][0]
#       encoder         : Lavc60.3.100 png
# frame=   40 fps= 17 q=-0.0 Lsize=N/A time=00:00:19.50 bitrate=N/A speed=8.24x    ts/s speed=N/A
# video:61681kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: unknown
# ffmpeg version 6.0 Copyright (c) 2000-2023 the FFmpeg developers
#   built with Apple clang version 15.0.0 (clang-1500.0.40.1)
#   configuration: --prefix=/opt/homebrew/Cellar/ffmpeg/6.0_1 --enable-shared --enable-pthreads --enable-version3 --cc=clang --host-cflags= --host-ldflags='-Wl,-ld_classic' --enable-ffplay --enable-gnutls --enable-gpl --enable-libaom --enable-libaribb24 --enable-libbluray --enable-libdav1d --enable-libjxl --enable-libmp3lame --enable-libopus --enable-librav1e --enable-librist --enable-librubberband --enable-libsnappy --enable-libsrt --enable-libsvtav1 --enable-libtesseract --enable-libtheora --enable-libvidstab --enable-libvmaf --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxml2 --enable-libxvid --enable-lzma --enable-libfontconfig --enable-libfreetype --enable-frei0r --enable-libass --enable-libopencore-amrnb --enable-libopencore-amrwb --enable-libopenjpeg --enable-libspeex --enable-libsoxr --enable-libzmq --enable-libzimg --disable-libjack --disable-indev=jack --enable-videotoolbox --enable-audiotoolbox --enable-neon
#   libavutil      58.  2.100 / 58.  2.100
#   libavcodec     60.  3.100 / 60.  3.100
#   libavformat    60.  3.100 / 60.  3.100
#   libavdevice    60.  1.100 / 60.  1.100
#   libavfilter     9.  3.100 /  9.  3.100
#   libswscale      7.  1.100 /  7.  1.100
#   libswresample   4. 10.100 /  4. 10.100
#   libpostproc    57.  1.100 / 57.  1.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from 'dataset_video/vimizer/5.mp4':
#   Metadata:
#     major_brand     : mp42
#     minor_version   : 0
#     compatible_brands: mp42mp41
#     creation_time   : 2023-04-07T08:54:28.000000Z
#   Duration: 00:00:20.00, start: 0.000000, bitrate: 9695 kb/s
#   Stream #0:0[0x1](eng): Video: h264 (Main) (avc1 / 0x31637661), yuv420p(progressive), 1920x1080 [SAR 1:1 DAR 16:9], 9354 kb/s, 30 fps, 30 tbr, 30k tbn (default)
#     Metadata:
#       creation_time   : 2023-04-07T08:54:28.000000Z
#       handler_name    : ?Mainconcept Video Media Handler
#       vendor_id       : [0][0][0][0]
#       encoder         : AVC Coding
#   Stream #0:1[0x2](eng): Audio: aac (LC) (mp4a / 0x6134706D), 48000 Hz, stereo, fltp, 317 kb/s (default)
#     Metadata:
#       creation_time   : 2023-04-07T08:54:28.000000Z
#       handler_name    : #Mainconcept MP4 Sound Media Handler
#       vendor_id       : [0][0][0][0]
# Stream mapping:
#   Stream #0:0 -> #0:0 (h264 (native) -> png (native))
# Press [q] to stop, [?] for help
# [swscaler @ 0x131028000] [swscaler @ 0x110008000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x131028000] [swscaler @ 0x110018000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x131028000] [swscaler @ 0x110028000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x131028000] [swscaler @ 0x110038000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x131028000] [swscaler @ 0x110048000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x131028000] [swscaler @ 0x131038000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x131028000] [swscaler @ 0x131048000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x131028000] [swscaler @ 0x131058000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x131028000] [swscaler @ 0x131068000] No accelerated colorspace conversion found from yuv420p to rgb24.
# Output #0, image2, to 'dataset/vimizer/3/img_%05d.png':
#   Metadata:
#     major_brand     : mp42
#     minor_version   : 0
#     compatible_brands: mp42mp41
#     encoder         : Lavf60.3.100
#   Stream #0:0(eng): Video: png, rgb24(pc, gbr/unknown/unknown, progressive), 1920x1080 [SAR 1:1 DAR 16:9], q=2-31, 200 kb/s, 2 fps, 2 tbn (default)
#     Metadata:
#       creation_time   : 2023-04-07T08:54:28.000000Z
#       handler_name    : ?Mainconcept Video Media Handler
#       vendor_id       : [0][0][0][0]
#       encoder         : Lavc60.3.100 png
# frame=   40 fps= 15 q=-0.0 Lsize=N/A time=00:00:19.50 bitrate=N/A speed=7.19x    ts/s speed=N/A
# video:66506kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: unknown
# ffmpeg version 6.0 Copyright (c) 2000-2023 the FFmpeg developers
#   built with Apple clang version 15.0.0 (clang-1500.0.40.1)
#   configuration: --prefix=/opt/homebrew/Cellar/ffmpeg/6.0_1 --enable-shared --enable-pthreads --enable-version3 --cc=clang --host-cflags= --host-ldflags='-Wl,-ld_classic' --enable-ffplay --enable-gnutls --enable-gpl --enable-libaom --enable-libaribb24 --enable-libbluray --enable-libdav1d --enable-libjxl --enable-libmp3lame --enable-libopus --enable-librav1e --enable-librist --enable-librubberband --enable-libsnappy --enable-libsrt --enable-libsvtav1 --enable-libtesseract --enable-libtheora --enable-libvidstab --enable-libvmaf --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxml2 --enable-libxvid --enable-lzma --enable-libfontconfig --enable-libfreetype --enable-frei0r --enable-libass --enable-libopencore-amrnb --enable-libopencore-amrwb --enable-libopenjpeg --enable-libspeex --enable-libsoxr --enable-libzmq --enable-libzimg --disable-libjack --disable-indev=jack --enable-videotoolbox --enable-audiotoolbox --enable-neon
#   libavutil      58.  2.100 / 58.  2.100
#   libavcodec     60.  3.100 / 60.  3.100
#   libavformat    60.  3.100 / 60.  3.100
#   libavdevice    60.  1.100 / 60.  1.100
#   libavfilter     9.  3.100 /  9.  3.100
#   libswscale      7.  1.100 /  7.  1.100
#   libswresample   4. 10.100 /  4. 10.100
#   libpostproc    57.  1.100 / 57.  1.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from 'dataset_video/vimizer/1.mp4':
#   Metadata:
#     major_brand     : mp42
#     minor_version   : 0
#     compatible_brands: mp42isomavc1
#     creation_time   : 2022-12-22T11:17:42.000000Z
#   Duration: 00:00:47.68, start: 0.000000, bitrate: 4014 kb/s
#   Stream #0:0[0x1](und): Video: h264 (High) (avc1 / 0x31637661), yuv420p(tv, bt709, progressive), 1920x1080, 3821 kb/s, 30 fps, 30 tbr, 30 tbn (default)
#     Metadata:
#       creation_time   : 2022-12-22T11:17:42.000000Z
#       handler_name    : Vimeo Artax Video Handler
#       vendor_id       : [0][0][0][0]
#       encoder         : AVC Coding
#   Stream #0:1[0x2](und): Audio: aac (LC) (mp4a / 0x6134706D), 48000 Hz, stereo, fltp, 189 kb/s (default)
#     Metadata:
#       creation_time   : 2022-12-22T11:17:42.000000Z
#       handler_name    : Vimeo Artax Audio Handler
#       vendor_id       : [0][0][0][0]
# Stream mapping:
#   Stream #0:0 -> #0:0 (h264 (native) -> png (native))
# Press [q] to stop, [?] for help
# [swscaler @ 0x128130000] [swscaler @ 0x108f60000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x128130000] [swscaler @ 0x108f70000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x128130000] [swscaler @ 0x108f80000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x128130000] [swscaler @ 0x108f90000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x128130000] [swscaler @ 0x108fa0000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x128130000] [swscaler @ 0x108fb0000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x128130000] [swscaler @ 0x108fc0000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x128130000] [swscaler @ 0x108fd0000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x128130000] [swscaler @ 0x108fe0000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x131578000] [swscaler @ 0x138270000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x131578000] [swscaler @ 0x131588000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x131578000] [swscaler @ 0x131598000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x131578000] [swscaler @ 0x1315a8000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x131578000] [swscaler @ 0x1315b8000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x131578000] [swscaler @ 0x1315c8000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x131578000] [swscaler @ 0x1315d8000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x131578000] [swscaler @ 0x1315e8000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x131578000] [swscaler @ 0x1315f8000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x131578000] [swscaler @ 0x131588000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x131578000] [swscaler @ 0x131598000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x131578000] [swscaler @ 0x1315a8000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x131578000] [swscaler @ 0x1315b8000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x131578000] [swscaler @ 0x1315c8000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x131578000] [swscaler @ 0x1315d8000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x131578000] [swscaler @ 0x1315e8000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x131578000] [swscaler @ 0x1315f8000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x131578000] [swscaler @ 0x131608000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x108fe0000] [swscaler @ 0x131578000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x108fe0000] [swscaler @ 0x131588000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x108fe0000] [swscaler @ 0x131598000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x108fe0000] [swscaler @ 0x1315a8000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x108fe0000] [swscaler @ 0x1315b8000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x108fe0000] [swscaler @ 0x1315c8000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x108fe0000] [swscaler @ 0x1315d8000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x108fe0000] [swscaler @ 0x1315e8000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x108fe0000] [swscaler @ 0x1315f8000] No accelerated colorspace conversion found from yuv420p to rgb24.
# Output #0, image2, to 'dataset/vimizer/4/img_%05d.png':
#   Metadata:
#     major_brand     : mp42
#     minor_version   : 0
#     compatible_brands: mp42isomavc1
#     encoder         : Lavf60.3.100
#   Stream #0:0(und): Video: png, rgb24(pc, gbr/bt709/bt709, progressive), 1920x1080, q=2-31, 200 kb/s, 2 fps, 2 tbn (default)
#     Metadata:
#       creation_time   : 2022-12-22T11:17:42.000000Z
#       handler_name    : Vimeo Artax Video Handler
#       vendor_id       : [0][0][0][0]
#       encoder         : Lavc60.3.100 png
# frame=   95 fps= 19 q=-0.0 Lsize=N/A time=00:00:47.00 bitrate=N/A speed=9.24x    ts/s speed=N/A
# video:100977kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: unknown
# ffmpeg version 6.0 Copyright (c) 2000-2023 the FFmpeg developers
#   built with Apple clang version 15.0.0 (clang-1500.0.40.1)
#   configuration: --prefix=/opt/homebrew/Cellar/ffmpeg/6.0_1 --enable-shared --enable-pthreads --enable-version3 --cc=clang --host-cflags= --host-ldflags='-Wl,-ld_classic' --enable-ffplay --enable-gnutls --enable-gpl --enable-libaom --enable-libaribb24 --enable-libbluray --enable-libdav1d --enable-libjxl --enable-libmp3lame --enable-libopus --enable-librav1e --enable-librist --enable-librubberband --enable-libsnappy --enable-libsrt --enable-libsvtav1 --enable-libtesseract --enable-libtheora --enable-libvidstab --enable-libvmaf --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxml2 --enable-libxvid --enable-lzma --enable-libfontconfig --enable-libfreetype --enable-frei0r --enable-libass --enable-libopencore-amrnb --enable-libopencore-amrwb --enable-libopenjpeg --enable-libspeex --enable-libsoxr --enable-libzmq --enable-libzimg --disable-libjack --disable-indev=jack --enable-videotoolbox --enable-audiotoolbox --enable-neon
#   libavutil      58.  2.100 / 58.  2.100
#   libavcodec     60.  3.100 / 60.  3.100
#   libavformat    60.  3.100 / 60.  3.100
#   libavdevice    60.  1.100 / 60.  1.100
#   libavfilter     9.  3.100 /  9.  3.100
#   libswscale      7.  1.100 /  7.  1.100
#   libswresample   4. 10.100 /  4. 10.100
#   libpostproc    57.  1.100 / 57.  1.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from 'dataset_video/vimizer/0.mp4':
#   Metadata:
#     major_brand     : mp42
#     minor_version   : 0
#     compatible_brands: mp42mp41
#     creation_time   : 2023-03-07T16:13:26.000000Z
#   Duration: 00:00:15.00, start: 0.000000, bitrate: 13062 kb/s
#   Stream #0:0[0x1](eng): Video: h264 (Main) (avc1 / 0x31637661), yuv420p(progressive), 1920x1080 [SAR 1:1 DAR 16:9], 12634 kb/s, 24 fps, 24 tbr, 24k tbn (default)
#     Metadata:
#       creation_time   : 2023-03-07T16:13:26.000000Z
#       handler_name    : ?Mainconcept Video Media Handler
#       vendor_id       : [0][0][0][0]
#       encoder         : AVC Coding
#   Stream #0:1[0x2](eng): Audio: aac (LC) (mp4a / 0x6134706D), 48000 Hz, stereo, fltp, 317 kb/s (default)
#     Metadata:
#       creation_time   : 2023-03-07T16:13:26.000000Z
#       handler_name    : #Mainconcept MP4 Sound Media Handler
#       vendor_id       : [0][0][0][0]
# Stream mapping:
#   Stream #0:0 -> #0:0 (h264 (native) -> png (native))
# Press [q] to stop, [?] for help
# [swscaler @ 0x151b18000] [swscaler @ 0x1100c0000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x151b18000] [swscaler @ 0x1100d0000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x151b18000] [swscaler @ 0x140bd0000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x151b18000] [swscaler @ 0x140be0000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x151b18000] [swscaler @ 0x140bf0000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x151b18000] [swscaler @ 0x140c00000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x151b18000] [swscaler @ 0x140c10000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x151b18000] [swscaler @ 0x140c20000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x151b18000] [swscaler @ 0x140c30000] No accelerated colorspace conversion found from yuv420p to rgb24.
# Output #0, image2, to 'dataset/vimizer/5/img_%05d.png':
#   Metadata:
#     major_brand     : mp42
#     minor_version   : 0
#     compatible_brands: mp42mp41
#     encoder         : Lavf60.3.100
#   Stream #0:0(eng): Video: png, rgb24(pc, gbr/unknown/unknown, progressive), 1920x1080 [SAR 1:1 DAR 16:9], q=2-31, 200 kb/s, 2 fps, 2 tbn (default)
#     Metadata:
#       creation_time   : 2023-03-07T16:13:26.000000Z
#       handler_name    : ?Mainconcept Video Media Handler
#       vendor_id       : [0][0][0][0]
#       encoder         : Lavc60.3.100 png
# frame=   30 fps= 18 q=-0.0 Lsize=N/A time=00:00:14.50 bitrate=N/A speed=8.66x    ts/s speed=N/A
# video:47608kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: unknown
# ffmpeg version 6.0 Copyright (c) 2000-2023 the FFmpeg developers
#   built with Apple clang version 15.0.0 (clang-1500.0.40.1)
#   configuration: --prefix=/opt/homebrew/Cellar/ffmpeg/6.0_1 --enable-shared --enable-pthreads --enable-version3 --cc=clang --host-cflags= --host-ldflags='-Wl,-ld_classic' --enable-ffplay --enable-gnutls --enable-gpl --enable-libaom --enable-libaribb24 --enable-libbluray --enable-libdav1d --enable-libjxl --enable-libmp3lame --enable-libopus --enable-librav1e --enable-librist --enable-librubberband --enable-libsnappy --enable-libsrt --enable-libsvtav1 --enable-libtesseract --enable-libtheora --enable-libvidstab --enable-libvmaf --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxml2 --enable-libxvid --enable-lzma --enable-libfontconfig --enable-libfreetype --enable-frei0r --enable-libass --enable-libopencore-amrnb --enable-libopencore-amrwb --enable-libopenjpeg --enable-libspeex --enable-libsoxr --enable-libzmq --enable-libzimg --disable-libjack --disable-indev=jack --enable-videotoolbox --enable-audiotoolbox --enable-neon
#   libavutil      58.  2.100 / 58.  2.100
#   libavcodec     60.  3.100 / 60.  3.100
#   libavformat    60.  3.100 / 60.  3.100
#   libavdevice    60.  1.100 / 60.  1.100
#   libavfilter     9.  3.100 /  9.  3.100
#   libswscale      7.  1.100 /  7.  1.100
#   libswresample   4. 10.100 /  4. 10.100
#   libpostproc    57.  1.100 / 57.  1.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from 'dataset_video/vimizer/2.mp4':
#   Metadata:
#     major_brand     : mp42
#     minor_version   : 0
#     compatible_brands: mp42mp41
#     creation_time   : 2023-07-20T08:24:36.000000Z
#   Duration: 00:00:20.00, start: 0.000000, bitrate: 9667 kb/s
#   Stream #0:0[0x1](eng): Video: h264 (Main) (avc1 / 0x31637661), yuv420p(tv, bt709, progressive), 1920x1080, 9325 kb/s, 25 fps, 25 tbr, 25k tbn (default)
#     Metadata:
#       creation_time   : 2023-07-20T08:24:36.000000Z
#       handler_name    : ?Mainconcept Video Media Handler
#       vendor_id       : [0][0][0][0]
#       encoder         : AVC Coding
#   Stream #0:1[0x2](eng): Audio: aac (LC) (mp4a / 0x6134706D), 48000 Hz, stereo, fltp, 317 kb/s (default)
#     Metadata:
#       creation_time   : 2023-07-20T08:24:37.000000Z
#       handler_name    : #Mainconcept MP4 Sound Media Handler
#       vendor_id       : [0][0][0][0]
# Stream mapping:
#   Stream #0:0 -> #0:0 (h264 (native) -> png (native))
# Press [q] to stop, [?] for help
# [swscaler @ 0x128f90000] [swscaler @ 0x128fa0000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x128f90000] [swscaler @ 0x128fb0000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x128f90000] [swscaler @ 0x128fc0000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x128f90000] [swscaler @ 0x128fd0000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x128f90000] [swscaler @ 0x128fe0000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x128f90000] [swscaler @ 0x128ff0000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x128f90000] [swscaler @ 0x129000000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x128f90000] [swscaler @ 0x129010000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x128f90000] [swscaler @ 0x129020000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x128f90000] [swscaler @ 0x170008000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x128f90000] [swscaler @ 0x170018000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x128f90000] [swscaler @ 0x170028000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x128f90000] [swscaler @ 0x170038000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x128f90000] [swscaler @ 0x170048000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x128f90000] [swscaler @ 0x1188a8000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x128f90000] [swscaler @ 0x1188b8000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x128f90000] [swscaler @ 0x1188c8000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x128f90000] [swscaler @ 0x1188d8000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x150208000] [swscaler @ 0x1381e8000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x150208000] [swscaler @ 0x1381f8000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x150208000] [swscaler @ 0x138208000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x150208000] [swscaler @ 0x138f88000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x150208000] [swscaler @ 0x138f98000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x150208000] [swscaler @ 0x138fa8000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x150208000] [swscaler @ 0x138fb8000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x150208000] [swscaler @ 0x138fc8000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x150208000] [swscaler @ 0x138fd8000] No accelerated colorspace conversion found from yuv420p to rgb24.
#     Last message repeated 1 times
# [swscaler @ 0x150208000] [swscaler @ 0x1381e8000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x150208000] [swscaler @ 0x1381f8000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x150208000] [swscaler @ 0x138208000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x150208000] [swscaler @ 0x138f88000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x150208000] [swscaler @ 0x138f98000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x150208000] [swscaler @ 0x138fa8000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x150208000] [swscaler @ 0x138fb8000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x150208000] [swscaler @ 0x138fc8000] No accelerated colorspace conversion found from yuv420p to rgb24.
# Output #0, image2, to 'dataset/vimizer/6/img_%05d.png':
#   Metadata:
#     major_brand     : mp42
#     minor_version   : 0
#     compatible_brands: mp42mp41
#     encoder         : Lavf60.3.100
#   Stream #0:0(eng): Video: png, rgb24(pc, gbr/bt709/bt709, progressive), 1920x1080, q=2-31, 200 kb/s, 2 fps, 2 tbn (default)
#     Metadata:
#       creation_time   : 2023-07-20T08:24:36.000000Z
#       handler_name    : ?Mainconcept Video Media Handler
#       vendor_id       : [0][0][0][0]
#       encoder         : Lavc60.3.100 png
# frame=   40 fps= 18 q=-0.0 Lsize=N/A time=00:00:19.50 bitrate=N/A speed=8.76x    ts/s speed=N/A
# video:43153kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: unknown
# ffmpeg version 6.0 Copyright (c) 2000-2023 the FFmpeg developers
#   built with Apple clang version 15.0.0 (clang-1500.0.40.1)
#   configuration: --prefix=/opt/homebrew/Cellar/ffmpeg/6.0_1 --enable-shared --enable-pthreads --enable-version3 --cc=clang --host-cflags= --host-ldflags='-Wl,-ld_classic' --enable-ffplay --enable-gnutls --enable-gpl --enable-libaom --enable-libaribb24 --enable-libbluray --enable-libdav1d --enable-libjxl --enable-libmp3lame --enable-libopus --enable-librav1e --enable-librist --enable-librubberband --enable-libsnappy --enable-libsrt --enable-libsvtav1 --enable-libtesseract --enable-libtheora --enable-libvidstab --enable-libvmaf --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxml2 --enable-libxvid --enable-lzma --enable-libfontconfig --enable-libfreetype --enable-frei0r --enable-libass --enable-libopencore-amrnb --enable-libopencore-amrwb --enable-libopenjpeg --enable-libspeex --enable-libsoxr --enable-libzmq --enable-libzimg --disable-libjack --disable-indev=jack --enable-videotoolbox --enable-audiotoolbox --enable-neon
#   libavutil      58.  2.100 / 58.  2.100
#   libavcodec     60.  3.100 / 60.  3.100
#   libavformat    60.  3.100 / 60.  3.100
#   libavdevice    60.  1.100 / 60.  1.100
#   libavfilter     9.  3.100 /  9.  3.100
#   libswscale      7.  1.100 /  7.  1.100
#   libswresample   4. 10.100 /  4. 10.100
#   libpostproc    57.  1.100 / 57.  1.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from 'dataset_video/vimizer/3.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf58.76.100
#   Duration: 00:00:15.04, start: 0.000000, bitrate: 12831 kb/s
#   Stream #0:0[0x1](und): Video: h264 (High) (avc1 / 0x31637661), yuv420p(tv, bt709, progressive), 1920x1080, 12489 kb/s, 25 fps, 25 tbr, 12800 tbn (default)
#     Metadata:
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
#       timecode        : 00:00:00:00
#   Stream #0:1[0x2](und): Audio: aac (LC) (mp4a / 0x6134706D), 48000 Hz, stereo, fltp, 368 kb/s (default)
#     Metadata:
#       handler_name    : SoundHandler
#       vendor_id       : [0][0][0][0]
#   Stream #0:2[0x3](eng): Data: none (tmcd / 0x64636D74), 0 kb/s
#     Metadata:
#       handler_name    : VideoHandler
#       timecode        : 00:00:00:00
# Stream mapping:
#   Stream #0:0 -> #0:0 (h264 (native) -> png (native))
# Press [q] to stop, [?] for help
# [swscaler @ 0x148018000] [swscaler @ 0x150008000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x148018000] [swscaler @ 0x150018000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x148018000] [swscaler @ 0x150028000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x148018000] [swscaler @ 0x150038000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x148018000] [swscaler @ 0x150048000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x148018000] [swscaler @ 0x150058000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x148018000] [swscaler @ 0x150068000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x148018000] [swscaler @ 0x150078000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x148018000] [swscaler @ 0x150088000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x130848000] [swscaler @ 0x148018000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x130848000] [swscaler @ 0x148090000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x130848000] [swscaler @ 0x1480a0000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x130848000] [swscaler @ 0x148050000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x130848000] [swscaler @ 0x148060000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x130848000] [swscaler @ 0x1480b0000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x130848000] [swscaler @ 0x140040000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x130848000] [swscaler @ 0x140488000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x130848000] [swscaler @ 0x140498000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x150088000] [swscaler @ 0x150008000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x150088000] [swscaler @ 0x150018000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x150088000] [swscaler @ 0x150028000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x150088000] [swscaler @ 0x150038000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x150088000] [swscaler @ 0x150048000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x150088000] [swscaler @ 0x150058000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x150088000] [swscaler @ 0x150068000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x150088000] [swscaler @ 0x140498000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x150088000] [swscaler @ 0x140488000] No accelerated colorspace conversion found from yuv420p to rgb24.
#     Last message repeated 1 times
# [swscaler @ 0x150088000] [swscaler @ 0x140498000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x150088000] [swscaler @ 0x140040000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x150088000] [swscaler @ 0x140068000] No accelerated colorspace conversion found from yuv420p to rgb24.
# ...
#   Metadata:
#     minor_version   : 512
#     major_brand     : isom
#     compatible_brands: isomiso2avc1mp41
#     comment         : vid:v09025g40000clofdinog65va1hd7600
#     encoder         : Lavf60.3.100
#   Stream #0:0(und): Video: png, rgb24(pc, gbr/bt709/bt709, progressive), 1024x576 [SAR 1:1 DAR 16:9], q=2-31, 200 kb/s, 2 fps, 2 tbn (default)
#     Metadata:
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
#       encoder         : Lavc60.3.100 png
# frame=   30 fps=0.0 q=-0.0 Lsize=N/A time=00:00:14.50 bitrate=N/A speed=30.2x    ts/s speed=N/A
# video:9695kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: unknown
# ffmpeg version 6.0 Copyright (c) 2000-2023 the FFmpeg developers
#   built with Apple clang version 15.0.0 (clang-1500.0.40.1)
#   configuration: --prefix=/opt/homebrew/Cellar/ffmpeg/6.0_1 --enable-shared --enable-pthreads --enable-version3 --cc=clang --host-cflags= --host-ldflags='-Wl,-ld_classic' --enable-ffplay --enable-gnutls --enable-gpl --enable-libaom --enable-libaribb24 --enable-libbluray --enable-libdav1d --enable-libjxl --enable-libmp3lame --enable-libopus --enable-librav1e --enable-librist --enable-librubberband --enable-libsnappy --enable-libsrt --enable-libsvtav1 --enable-libtesseract --enable-libtheora --enable-libvidstab --enable-libvmaf --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxml2 --enable-libxvid --enable-lzma --enable-libfontconfig --enable-libfreetype --enable-frei0r --enable-libass --enable-libopencore-amrnb --enable-libopencore-amrwb --enable-libopenjpeg --enable-libspeex --enable-libsoxr --enable-libzmq --enable-libzimg --disable-libjack --disable-indev=jack --enable-videotoolbox --enable-audiotoolbox --enable-neon
#   libavutil      58.  2.100 / 58.  2.100
#   libavcodec     60.  3.100 / 60.  3.100
#   libavformat    60.  3.100 / 60.  3.100
#   libavdevice    60.  1.100 / 60.  1.100
#   libavfilter     9.  3.100 /  9.  3.100
#   libswscale      7.  1.100 /  7.  1.100
#   libswresample   4. 10.100 /  4. 10.100
#   libpostproc    57.  1.100 / 57.  1.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from 'dataset_video/tiktok/10.mp4':
#   Metadata:
#     minor_version   : 512
#     major_brand     : isom
#     compatible_brands: isomiso2avc1mp41
#     comment         : vid:v09025g40000clorgrvog65k5hpk3nfg
#     encoder         : Lavf58.20.100
#   Duration: 00:00:15.02, start: 0.000000, bitrate: 559 kb/s
#   Stream #0:0[0x1](und): Video: h264 (High) (avc1 / 0x31637661), yuv420p(progressive), 1024x576 [SAR 1:1 DAR 16:9], 487 kb/s, 25 fps, 25 tbr, 12800 tbn (default)
#     Metadata:
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
#   Stream #0:1[0x2](und): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 64 kb/s (default)
#     Metadata:
#       handler_name    : SoundHandler
#       vendor_id       : [0][0][0][0]
# Stream mapping:
#   Stream #0:0 -> #0:0 (h264 (native) -> png (native))
# Press [q] to stop, [?] for help
# [swscaler @ 0x150108000] [swscaler @ 0x150118000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x150108000] [swscaler @ 0x150128000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x150108000] [swscaler @ 0x150138000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x150108000] [swscaler @ 0x150148000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x150108000] [swscaler @ 0x150158000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x150108000] [swscaler @ 0x150168000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x150108000] [swscaler @ 0x150178000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x150108000] [swscaler @ 0x150da0000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x150108000] [swscaler @ 0x150db0000] No accelerated colorspace conversion found from yuv420p to rgb24.
# Output #0, image2, to 'dataset/tiktok/8/img_%05d.png':
#   Metadata:
#     minor_version   : 512
#     major_brand     : isom
#     compatible_brands: isomiso2avc1mp41
#     comment         : vid:v09025g40000clorgrvog65k5hpk3nfg
#     encoder         : Lavf60.3.100
#   Stream #0:0(und): Video: png, rgb24(pc, gbr/unknown/unknown, progressive), 1024x576 [SAR 1:1 DAR 16:9], q=2-31, 200 kb/s, 2 fps, 2 tbn (default)
#     Metadata:
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
#       encoder         : Lavc60.3.100 png
# frame=   30 fps=0.0 q=-0.0 Lsize=N/A time=00:00:14.50 bitrate=N/A speed=33.7x    ts/s speed=N/A
# video:15290kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: unknown
# ffmpeg version 6.0 Copyright (c) 2000-2023 the FFmpeg developers
#   built with Apple clang version 15.0.0 (clang-1500.0.40.1)
#   configuration: --prefix=/opt/homebrew/Cellar/ffmpeg/6.0_1 --enable-shared --enable-pthreads --enable-version3 --cc=clang --host-cflags= --host-ldflags='-Wl,-ld_classic' --enable-ffplay --enable-gnutls --enable-gpl --enable-libaom --enable-libaribb24 --enable-libbluray --enable-libdav1d --enable-libjxl --enable-libmp3lame --enable-libopus --enable-librav1e --enable-librist --enable-librubberband --enable-libsnappy --enable-libsrt --enable-libsvtav1 --enable-libtesseract --enable-libtheora --enable-libvidstab --enable-libvmaf --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxml2 --enable-libxvid --enable-lzma --enable-libfontconfig --enable-libfreetype --enable-frei0r --enable-libass --enable-libopencore-amrnb --enable-libopencore-amrwb --enable-libopenjpeg --enable-libspeex --enable-libsoxr --enable-libzmq --enable-libzimg --disable-libjack --disable-indev=jack --enable-videotoolbox --enable-audiotoolbox --enable-neon
#   libavutil      58.  2.100 / 58.  2.100
#   libavcodec     60.  3.100 / 60.  3.100
#   libavformat    60.  3.100 / 60.  3.100
#   libavdevice    60.  1.100 / 60.  1.100
#   libavfilter     9.  3.100 /  9.  3.100
#   libswscale      7.  1.100 /  7.  1.100
#   libswresample   4. 10.100 /  4. 10.100
#   libpostproc    57.  1.100 / 57.  1.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from 'dataset_video/tiktok/8.mp4':
#   Metadata:
#     minor_version   : 512
#     major_brand     : isom
#     compatible_brands: isomiso2avc1mp41
#     comment         : vid:v09025g40000clorg2fog65si1pum0e0
#     encoder         : Lavf58.20.100
#   Duration: 00:00:15.02, start: 0.000000, bitrate: 564 kb/s
#   Stream #0:0[0x1](und): Video: h264 (High) (avc1 / 0x31637661), yuv420p(tv, bt709, progressive), 1024x576 [SAR 1:1 DAR 16:9], 493 kb/s, 25 fps, 25 tbr, 12800 tbn (default)
#     Metadata:
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
#   Stream #0:1[0x2](und): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 64 kb/s (default)
#     Metadata:
#       handler_name    : SoundHandler
#       vendor_id       : [0][0][0][0]
# Stream mapping:
#   Stream #0:0 -> #0:0 (h264 (native) -> png (native))
# Press [q] to stop, [?] for help
# [swscaler @ 0x110430000] [swscaler @ 0x128d08000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x110430000] [swscaler @ 0x128d18000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x110430000] [swscaler @ 0x128d28000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x110430000] [swscaler @ 0x128d38000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x110430000] [swscaler @ 0x128d48000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x110430000] [swscaler @ 0x128d58000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x110430000] [swscaler @ 0x128d68000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x110430000] [swscaler @ 0x128d78000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x110430000] [swscaler @ 0x128d88000] No accelerated colorspace conversion found from yuv420p to rgb24.
#     Last message repeated 1 times
# [swscaler @ 0x110430000] [swscaler @ 0x128d08000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x110430000] [swscaler @ 0x128d18000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x110430000] [swscaler @ 0x128d28000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x110430000] [swscaler @ 0x128d38000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x110430000] [swscaler @ 0x128d48000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x110430000] [swscaler @ 0x128d58000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x110430000] [swscaler @ 0x128d68000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x110430000] [swscaler @ 0x128d78000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x130340000] [swscaler @ 0x110430000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x130340000] [swscaler @ 0x110440000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x130340000] [swscaler @ 0x110450000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x130340000] [swscaler @ 0x110460000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x130340000] [swscaler @ 0x110470000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x130340000] [swscaler @ 0x110480000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x130340000] [swscaler @ 0x110490000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x130340000] [swscaler @ 0x1104a0000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x130340000] [swscaler @ 0x1104b0000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x128d78000] [swscaler @ 0x128d88000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x128d78000] [swscaler @ 0x128d08000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x128d78000] [swscaler @ 0x128d18000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x128d78000] [swscaler @ 0x128d28000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x128d78000] [swscaler @ 0x128d38000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x128d78000] [swscaler @ 0x128d48000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x128d78000] [swscaler @ 0x128d58000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x128d78000] [swscaler @ 0x128d68000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x128d78000] [swscaler @ 0x128108000] No accelerated colorspace conversion found from yuv420p to rgb24.
# Output #0, image2, to 'dataset/tiktok/9/img_%05d.png':
#   Metadata:
#     minor_version   : 512
#     major_brand     : isom
#     compatible_brands: isomiso2avc1mp41
#     comment         : vid:v09025g40000clorg2fog65si1pum0e0
#     encoder         : Lavf60.3.100
#   Stream #0:0(und): Video: png, rgb24(pc, gbr/bt709/bt709, progressive), 1024x576 [SAR 1:1 DAR 16:9], q=2-31, 200 kb/s, 2 fps, 2 tbn (default)
#     Metadata:
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
#       encoder         : Lavc60.3.100 png
# frame=   30 fps=0.0 q=-0.0 Lsize=N/A time=00:00:14.50 bitrate=N/A speed=41.4x    ts/s speed=N/A
# video:10290kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: unknown
# ffmpeg version 6.0 Copyright (c) 2000-2023 the FFmpeg developers
#   built with Apple clang version 15.0.0 (clang-1500.0.40.1)
#   configuration: --prefix=/opt/homebrew/Cellar/ffmpeg/6.0_1 --enable-shared --enable-pthreads --enable-version3 --cc=clang --host-cflags= --host-ldflags='-Wl,-ld_classic' --enable-ffplay --enable-gnutls --enable-gpl --enable-libaom --enable-libaribb24 --enable-libbluray --enable-libdav1d --enable-libjxl --enable-libmp3lame --enable-libopus --enable-librav1e --enable-librist --enable-librubberband --enable-libsnappy --enable-libsrt --enable-libsvtav1 --enable-libtesseract --enable-libtheora --enable-libvidstab --enable-libvmaf --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxml2 --enable-libxvid --enable-lzma --enable-libfontconfig --enable-libfreetype --enable-frei0r --enable-libass --enable-libopencore-amrnb --enable-libopencore-amrwb --enable-libopenjpeg --enable-libspeex --enable-libsoxr --enable-libzmq --enable-libzimg --disable-libjack --disable-indev=jack --enable-videotoolbox --enable-audiotoolbox --enable-neon
#   libavutil      58.  2.100 / 58.  2.100
#   libavcodec     60.  3.100 / 60.  3.100
#   libavformat    60.  3.100 / 60.  3.100
#   libavdevice    60.  1.100 / 60.  1.100
#   libavfilter     9.  3.100 /  9.  3.100
#   libswscale      7.  1.100 /  7.  1.100
#   libswresample   4. 10.100 /  4. 10.100
#   libpostproc    57.  1.100 / 57.  1.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from 'dataset_video/tiktok/9.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     comment         : vid:v09025g40000clorg8nog65ghqc0cun0
#     encoder         : Lavf58.76.100
#   Duration: 00:00:23.02, start: 0.000000, bitrate: 614 kb/s
#   Stream #0:0[0x1](und): Video: h264 (High) (avc1 / 0x31637661), yuv420p(progressive), 1024x576 [SAR 1:1 DAR 16:9], 577 kb/s, 25 fps, 25 tbr, 12800 tbn (default)
#     Metadata:
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
#   Stream #0:1[0x2](und): Audio: aac (HE-AACv2) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 32 kb/s (default)
#     Metadata:
#       handler_name    : SoundHandler
#       vendor_id       : [0][0][0][0]
# Stream mapping:
#   Stream #0:0 -> #0:0 (h264 (native) -> png (native))
# Press [q] to stop, [?] for help
# [swscaler @ 0x140220000] [swscaler @ 0x120680000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x140220000] [swscaler @ 0x120690000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x140220000] [swscaler @ 0x1206a0000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x140220000] [swscaler @ 0x1206b0000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x140220000] [swscaler @ 0x1206c0000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x140220000] [swscaler @ 0x1206d0000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x140220000] [swscaler @ 0x1206e0000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x140220000] [swscaler @ 0x1206f0000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x140220000] [swscaler @ 0x120700000] No accelerated colorspace conversion found from yuv420p to rgb24.
# Output #0, image2, to 'dataset/tiktok/10/img_%05d.png':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     comment         : vid:v09025g40000clorg8nog65ghqc0cun0
#     encoder         : Lavf60.3.100
#   Stream #0:0(und): Video: png, rgb24(pc, gbr/unknown/unknown, progressive), 1024x576 [SAR 1:1 DAR 16:9], q=2-31, 200 kb/s, 2 fps, 2 tbn (default)
#     Metadata:
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
#       encoder         : Lavc60.3.100 png
# frame=   46 fps=0.0 q=-0.0 Lsize=N/A time=00:00:22.50 bitrate=N/A speed=36.3x    ts/s speed=N/A
# video:13816kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: unknown
