# %% [markdown]
# # DataLoader
# <p> Tutorial link: https://github.com/RaivoKoot/Video-Dataset-Loading-Pytorch or https://video-dataset-loading-pytorch.readthedocs.io/en/latest/ </p>

# %% [markdown]
# ## Database preparation
# <li> Input : 3 folders named ( tiktok, youtube, vimizer) which contains the mp4 videos  </li>
# <li> For each Folders : Create an homologue folder which contains num_videos folders. All of these folders named by the index of the video contain each frames of the same video. </li>
# <li> Annotations.txt file generation </li>
# <li> Extraction of I frames </li>

# %% [markdown]
# ### Creation of the architecture

# %%
### Useful Path ###
dataset_video= 'dataset_video'
dataset = 'dataset_train'
dataset_test = 'dataset_test'
nmbr_video_test=2

# %%
##### Librairies #####
import os
import cv2
import subprocess
import shutil

# %%
### Nettoyer la base de donnée ######
# remove all the folder of the database
shutil.rmtree(dataset)
shutil.rmtree(dataset_test)

# %%
####### Database creation ########
os.makedirs(dataset)
os.makedirs(dataset_test)
classe=-1

for folder in os.listdir(dataset_video):

    classe=classe+1
    folder_path = dataset + '/'+ folder
    folder_path_test = dataset_test + '/'+ folder
    os.makedirs(folder_path)
    os.makedirs(folder_path_test)

    print('creation of the folder ' + folder)

    folder_video_path = dataset_video + '/'+ folder


    for i, video in  enumerate(os.listdir(folder_video_path)) :

        if i < len(os.listdir(folder_video_path))- nmbr_video_test:
            video_path = folder_video_path + '/' + video
            output_folder_video_path = folder_path + '/' + str(i)

            # Creation of the frame folder for the video i 
            os.makedirs(output_folder_video_path)

            # Extraction of the frames in this folder
            # command = "ffmpeg -i " + video_path + " -vf fps=2 " + output_folder_video_path +"/img_%05d.png"
            # Extraction of the i frame -frame_pts true
            command = "ffmpeg -skip_frame nokey -i " + video_path + " -vsync vfr  " + output_folder_video_path +"/img_%05d.png"
            subprocess.run(command, shell=True)

            #Ajout de la ligne dans annotation.txt
            elements = os.listdir(output_folder_video_path)
            compteur= len(elements)
            

            with open('annotation.txt', 'a') as file:
                file.write(folder + '/' + str(i)+ " 1 " + str(compteur) + " " + str(classe) + "\n")
        
        else :
            video_path = folder_video_path + '/' + video
            output_folder_video_path = folder_path_test + '/' + str(i)

            # Creation of the frame folder for the video i 
            os.makedirs(output_folder_video_path)

            # Extraction of the frames in this folder
            # command = "ffmpeg -i " + video_path + " -vf fps=2 " + output_folder_video_path +"/img_%05d.png"
            # Extraction of the i frame 
            command = "ffmpeg -skip_frame nokey -i " + video_path + " -vsync vfr  " + output_folder_video_path +"/img_%05d.png"
            subprocess.run(command, shell=True)


            #Ajout de la ligne dans annotation.txt
            elements = os.listdir(output_folder_video_path)
            compteur= len(elements)
            

            with open('annotation_test.txt', 'a') as file:
                file.write(folder + '/' + str(i)+ " 1 " + str(compteur) + " " + str(classe) + "\n")
# Out:
# creation of the folder vimizer
# ffmpeg version 6.0 Copyright (c) 2000-2023 the FFmpeg developers
#   built with Apple clang version 15.0.0 (clang-1500.0.40.1)
#   configuration: --prefix=/opt/homebrew/Cellar/ffmpeg/6.0_1 --enable-shared --enable-pthreads --enable-version3 --cc=clang --host-cflags= --host-ldflags='-Wl,-ld_classic' --enable-ffplay --enable-gnutls --enable-gpl --enable-libaom --enable-libaribb24 --enable-libbluray --enable-libdav1d --enable-libjxl --enable-libmp3lame --enable-libopus --enable-librav1e --enable-librist --enable-librubberband --enable-libsnappy --enable-libsrt --enable-libsvtav1 --enable-libtesseract --enable-libtheora --enable-libvidstab --enable-libvmaf --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxml2 --enable-libxvid --enable-lzma --enable-libfontconfig --enable-libfreetype --enable-frei0r --enable-libass --enable-libopencore-amrnb --enable-libopencore-amrwb --enable-libopenjpeg --enable-libspeex --enable-libsoxr --enable-libzmq --enable-libzimg --disable-libjack --disable-indev=jack --enable-videotoolbox --enable-audiotoolbox --enable-neon
#   libavutil      58.  2.100 / 58.  2.100
#   libavcodec     60.  3.100 / 60.  3.100
#   libavformat    60.  3.100 / 60.  3.100
#   libavdevice    60.  1.100 / 60.  1.100
#   libavfilter     9.  3.100 /  9.  3.100
#   libswscale      7.  1.100 /  7.  1.100
#   libswresample   4. 10.100 /  4. 10.100
#   libpostproc    57.  1.100 / 57.  1.100
# -vsync is deprecated. Use -fps_mode
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from 'dataset_video/vimizer/7.mp4':
#   Metadata:
#     major_brand     : mp42
#     minor_version   : 0
#     compatible_brands: mp42mp41
#     creation_time   : 2023-04-12T09:04:07.000000Z
#   Duration: 00:00:20.00, start: 0.000000, bitrate: 9569 kb/s
#   Stream #0:0[0x1](eng): Video: h264 (High) (avc1 / 0x31637661), yuv420p(tv, bt709, progressive), 1920x1080 [SAR 1:1 DAR 16:9], 9226 kb/s, 25 fps, 25 tbr, 25k tbn (default)
#     Metadata:
#       creation_time   : 2023-04-12T09:04:07.000000Z
#       handler_name    : ?Mainconcept Video Media Handler
#       vendor_id       : [0][0][0][0]
#       encoder         : AVC Coding
#   Stream #0:1[0x2](eng): Audio: aac (LC) (mp4a / 0x6134706D), 48000 Hz, stereo, fltp, 317 kb/s (default)
#     Metadata:
#       creation_time   : 2023-04-12T09:04:07.000000Z
#       handler_name    : #Mainconcept MP4 Sound Media Handler
#       vendor_id       : [0][0][0][0]
# Stream mapping:
#   Stream #0:0 -> #0:0 (h264 (native) -> png (native))
# Press [q] to stop, [?] for help
# [swscaler @ 0x128dc8000] [swscaler @ 0x128dd8000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x128dc8000] [swscaler @ 0x128de8000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x128dc8000] [swscaler @ 0x128df8000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x128dc8000] [swscaler @ 0x128e08000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x128dc8000] [swscaler @ 0x128e18000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x128dc8000] [swscaler @ 0x128e28000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x128dc8000] [swscaler @ 0x128e38000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x128dc8000] [swscaler @ 0x128e48000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x128dc8000] [swscaler @ 0x128e58000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x130008000] [swscaler @ 0x128dc8000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x130008000] [swscaler @ 0x128118000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x130008000] [swscaler @ 0x128128000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x130008000] [swscaler @ 0x128138000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x130008000] [swscaler @ 0x128dd8000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x130008000] [swscaler @ 0x128de8000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x130008000] [swscaler @ 0x128df8000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x130008000] [swscaler @ 0x128e08000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x130008000] [swscaler @ 0x128e18000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x128e18000] [swscaler @ 0x128118000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x128e18000] [swscaler @ 0x128128000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x128e18000] [swscaler @ 0x128138000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x128e18000] [swscaler @ 0x128e28000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x128e18000] [swscaler @ 0x128e38000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x128e18000] [swscaler @ 0x128e48000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x128e18000] [swscaler @ 0x128e58000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x128e18000] [swscaler @ 0x128dc8000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x128e18000] [swscaler @ 0x128dd8000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x130008000] [swscaler @ 0x1088d0000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x130008000] [swscaler @ 0x1088e0000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x130008000] [swscaler @ 0x1088f0000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x130008000] [swscaler @ 0x108900000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x130008000] [swscaler @ 0x108910000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x130008000] [swscaler @ 0x108920000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x130008000] [swscaler @ 0x108930000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x130008000] [swscaler @ 0x108940000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x130008000] [swscaler @ 0x108950000] No accelerated colorspace conversion found from yuv420p to rgb24.
# Output #0, image2, to 'dataset_train/vimizer/0/img_%05d.png':
#   Metadata:
#     major_brand     : mp42
#     minor_version   : 0
#     compatible_brands: mp42mp41
#     encoder         : Lavf60.3.100
#   Stream #0:0(eng): Video: png, rgb24(pc, gbr/bt709/bt709, progressive), 1920x1080 [SAR 1:1 DAR 16:9], q=2-31, 200 kb/s, 25 fps, 25 tbn (default)
#     Metadata:
#       creation_time   : 2023-04-12T09:04:07.000000Z
#       handler_name    : ?Mainconcept Video Media Handler
#       vendor_id       : [0][0][0][0]
#       encoder         : Lavc60.3.100 png
# frame=   12 fps=0.0 q=-0.0 Lsize=N/A time=00:00:18.88 bitrate=N/A speed=47.6x    ts/s speed=N/A
# video:23518kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: unknown
# ffmpeg version 6.0 Copyright (c) 2000-2023 the FFmpeg developers
#   built with Apple clang version 15.0.0 (clang-1500.0.40.1)
#   configuration: --prefix=/opt/homebrew/Cellar/ffmpeg/6.0_1 --enable-shared --enable-pthreads --enable-version3 --cc=clang --host-cflags= --host-ldflags='-Wl,-ld_classic' --enable-ffplay --enable-gnutls --enable-gpl --enable-libaom --enable-libaribb24 --enable-libbluray --enable-libdav1d --enable-libjxl --enable-libmp3lame --enable-libopus --enable-librav1e --enable-librist --enable-librubberband --enable-libsnappy --enable-libsrt --enable-libsvtav1 --enable-libtesseract --enable-libtheora --enable-libvidstab --enable-libvmaf --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxml2 --enable-libxvid --enable-lzma --enable-libfontconfig --enable-libfreetype --enable-frei0r --enable-libass --enable-libopencore-amrnb --enable-libopencore-amrwb --enable-libopenjpeg --enable-libspeex --enable-libsoxr --enable-libzmq --enable-libzimg --disable-libjack --disable-indev=jack --enable-videotoolbox --enable-audiotoolbox --enable-neon
#   libavutil      58.  2.100 / 58.  2.100
#   libavcodec     60.  3.100 / 60.  3.100
#   libavformat    60.  3.100 / 60.  3.100
#   libavdevice    60.  1.100 / 60.  1.100
#   libavfilter     9.  3.100 /  9.  3.100
#   libswscale      7.  1.100 /  7.  1.100
#   libswresample   4. 10.100 /  4. 10.100
#   libpostproc    57.  1.100 / 57.  1.100
# -vsync is deprecated. Use -fps_mode
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from 'dataset_video/vimizer/6.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf60.3.100
#     comment         : Create videos with https://clipchamp.com/en/video-editor - free online video editor, video compressor, video converter.
#   Duration: 00:00:53.07, start: 0.000000, bitrate: 3604 kb/s
#   Stream #0:0[0x1](und): Video: h264 (High) (avc1 / 0x31637661), yuv420p(progressive), 1920x1080 [SAR 1:1 DAR 16:9], 3479 kb/s, 30 fps, 30 tbr, 15360 tbn (default)
#     Metadata:
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
#       encoder         : Lavc60.3.100 libx264
#   Stream #0:1[0x2](und): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 128 kb/s (default)
#     Metadata:
#       handler_name    : SoundHandler
#       vendor_id       : [0][0][0][0]
# Stream mapping:
#   Stream #0:0 -> #0:0 (h264 (native) -> png (native))
# Press [q] to stop, [?] for help
# [swscaler @ 0x139500000] [swscaler @ 0x139510000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x139500000] [swscaler @ 0x139520000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x139500000] [swscaler @ 0x139530000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x139500000] [swscaler @ 0x139540000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x139500000] [swscaler @ 0x139550000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x139500000] [swscaler @ 0x139560000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x139500000] [swscaler @ 0x139570000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x139500000] [swscaler @ 0x139580000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x139500000] [swscaler @ 0x139590000] No accelerated colorspace conversion found from yuv420p to rgb24.
# Output #0, image2, to 'dataset_train/vimizer/1/img_%05d.png':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     comment         : Create videos with https://clipchamp.com/en/video-editor - free online video editor, video compressor, video converter.
#     encoder         : Lavf60.3.100
#   Stream #0:0(und): Video: png, rgb24(pc, gbr/unknown/unknown, progressive), 1920x1080 [SAR 1:1 DAR 16:9], q=2-31, 200 kb/s, 30 fps, 30 tbn (default)
#     Metadata:
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
#       encoder         : Lavc60.3.100 png
# frame=    7 fps=0.0 q=-0.0 Lsize=N/A time=00:00:47.83 bitrate=N/A speed= 162x    ts/s speed=N/A
# video:17044kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: unknown
# ffmpeg version 6.0 Copyright (c) 2000-2023 the FFmpeg developers
#   built with Apple clang version 15.0.0 (clang-1500.0.40.1)
#   configuration: --prefix=/opt/homebrew/Cellar/ffmpeg/6.0_1 --enable-shared --enable-pthreads --enable-version3 --cc=clang --host-cflags= --host-ldflags='-Wl,-ld_classic' --enable-ffplay --enable-gnutls --enable-gpl --enable-libaom --enable-libaribb24 --enable-libbluray --enable-libdav1d --enable-libjxl --enable-libmp3lame --enable-libopus --enable-librav1e --enable-librist --enable-librubberband --enable-libsnappy --enable-libsrt --enable-libsvtav1 --enable-libtesseract --enable-libtheora --enable-libvidstab --enable-libvmaf --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxml2 --enable-libxvid --enable-lzma --enable-libfontconfig --enable-libfreetype --enable-frei0r --enable-libass --enable-libopencore-amrnb --enable-libopencore-amrwb --enable-libopenjpeg --enable-libspeex --enable-libsoxr --enable-libzmq --enable-libzimg --disable-libjack --disable-indev=jack --enable-videotoolbox --enable-audiotoolbox --enable-neon
#   libavutil      58.  2.100 / 58.  2.100
#   libavcodec     60.  3.100 / 60.  3.100
#   libavformat    60.  3.100 / 60.  3.100
#   libavdevice    60.  1.100 / 60.  1.100
#   libavfilter     9.  3.100 /  9.  3.100
#   libswscale      7.  1.100 /  7.  1.100
#   libswresample   4. 10.100 /  4. 10.100
#   libpostproc    57.  1.100 / 57.  1.100
# -vsync is deprecated. Use -fps_mode
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from 'dataset_video/vimizer/4.mp4':
#   Metadata:
#     major_brand     : mp42
#     minor_version   : 0
#     compatible_brands: mp42mp41
#     creation_time   : 2023-07-03T15:18:23.000000Z
#   Duration: 00:00:20.00, start: 0.000000, bitrate: 9564 kb/s
#   Stream #0:0[0x1](eng): Video: h264 (Main) (avc1 / 0x31637661), yuv420p(tv, bt709, progressive), 1920x1080 [SAR 1:1 DAR 16:9], 9202 kb/s, 25 fps, 25 tbr, 25k tbn (default)
#     Metadata:
#       creation_time   : 2023-07-03T15:18:23.000000Z
#       handler_name    : ?Mainconcept Video Media Handler
#       vendor_id       : [0][0][0][0]
#       encoder         : AVC Coding
#   Stream #0:1[0x2](eng): Audio: aac (LC) (mp4a / 0x6134706D), 48000 Hz, stereo, fltp, 317 kb/s (default)
#     Metadata:
#       creation_time   : 2023-07-03T15:18:27.000000Z
#       handler_name    : #Mainconcept MP4 Sound Media Handler
#       vendor_id       : [0][0][0][0]
# Stream mapping:
#   Stream #0:0 -> #0:0 (h264 (native) -> png (native))
# Press [q] to stop, [?] for help
# [swscaler @ 0x130d78000] [swscaler @ 0x130d88000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x130d78000] [swscaler @ 0x130d98000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x130d78000] [swscaler @ 0x130da8000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x130d78000] [swscaler @ 0x130db8000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x130d78000] [swscaler @ 0x130dc8000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x130d78000] [swscaler @ 0x130dd8000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x130d78000] [swscaler @ 0x130de8000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x130d78000] [swscaler @ 0x130df8000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x130d78000] [swscaler @ 0x130e08000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x1381c8000] [swscaler @ 0x1403c8000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x1381c8000] [swscaler @ 0x1403d8000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x1381c8000] [swscaler @ 0x1403e8000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x1381c8000] [swscaler @ 0x1403f8000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x1381c8000] [swscaler @ 0x140408000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x1381c8000] [swscaler @ 0x140418000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x1381c8000] [swscaler @ 0x140428000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x1381c8000] [swscaler @ 0x140438000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x1381c8000] [swscaler @ 0x140448000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x130d78000] [swscaler @ 0x1300e8000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x130d78000] [swscaler @ 0x1300f8000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x130d78000] [swscaler @ 0x130108000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x130d78000] [swscaler @ 0x130d88000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x130d78000] [swscaler @ 0x130d98000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x130d78000] [swscaler @ 0x130da8000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x130d78000] [swscaler @ 0x130db8000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x130d78000] [swscaler @ 0x130dc8000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x130d78000] [swscaler @ 0x130dd8000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x140448000] [swscaler @ 0x1403c8000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x140448000] [swscaler @ 0x1403d8000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x140448000] [swscaler @ 0x1403e8000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x140448000] [swscaler @ 0x1403f8000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x140448000] [swscaler @ 0x140408000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x140448000] [swscaler @ 0x140418000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x140448000] [swscaler @ 0x140428000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x140448000] [swscaler @ 0x140438000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x140448000] [swscaler @ 0x140118000] No accelerated colorspace conversion found from yuv420p to rgb24.
# Output #0, image2, to 'dataset_train/vimizer/2/img_%05d.png':
#   Metadata:
#     major_brand     : mp42
#     minor_version   : 0
#     compatible_brands: mp42mp41
#     encoder         : Lavf60.3.100
#   Stream #0:0(eng): Video: png, rgb24(pc, gbr/bt709/bt709, progressive), 1920x1080 [SAR 1:1 DAR 16:9], q=2-31, 200 kb/s, 25 fps, 25 tbn (default)
#     Metadata:
#       creation_time   : 2023-07-03T15:18:23.000000Z
#       handler_name    : ?Mainconcept Video Media Handler
#       vendor_id       : [0][0][0][0]
#       encoder         : Lavc60.3.100 png
# frame=   13 fps=0.0 q=-0.0 Lsize=N/A time=00:00:18.88 bitrate=N/A speed=48.1x    ts/s speed=N/A
# video:22124kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: unknown
# ffmpeg version 6.0 Copyright (c) 2000-2023 the FFmpeg developers
#   built with Apple clang version 15.0.0 (clang-1500.0.40.1)
#   configuration: --prefix=/opt/homebrew/Cellar/ffmpeg/6.0_1 --enable-shared --enable-pthreads --enable-version3 --cc=clang --host-cflags= --host-ldflags='-Wl,-ld_classic' --enable-ffplay --enable-gnutls --enable-gpl --enable-libaom --enable-libaribb24 --enable-libbluray --enable-libdav1d --enable-libjxl --enable-libmp3lame --enable-libopus --enable-librav1e --enable-librist --enable-librubberband --enable-libsnappy --enable-libsrt --enable-libsvtav1 --enable-libtesseract --enable-libtheora --enable-libvidstab --enable-libvmaf --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxml2 --enable-libxvid --enable-lzma --enable-libfontconfig --enable-libfreetype --enable-frei0r --enable-libass --enable-libopencore-amrnb --enable-libopencore-amrwb --enable-libopenjpeg --enable-libspeex --enable-libsoxr --enable-libzmq --enable-libzimg --disable-libjack --disable-indev=jack --enable-videotoolbox --enable-audiotoolbox --enable-neon
#   libavutil      58.  2.100 / 58.  2.100
#   libavcodec     60.  3.100 / 60.  3.100
#   libavformat    60.  3.100 / 60.  3.100
#   libavdevice    60.  1.100 / 60.  1.100
#   libavfilter     9.  3.100 /  9.  3.100
#   libswscale      7.  1.100 /  7.  1.100
#   libswresample   4. 10.100 /  4. 10.100
#   libpostproc    57.  1.100 / 57.  1.100
# -vsync is deprecated. Use -fps_mode
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from 'dataset_video/vimizer/5.mp4':
#   Metadata:
#     major_brand     : mp42
#     minor_version   : 0
#     compatible_brands: mp42mp41
#     creation_time   : 2023-04-07T08:54:28.000000Z
#   Duration: 00:00:20.00, start: 0.000000, bitrate: 9695 kb/s
#   Stream #0:0[0x1](eng): Video: h264 (Main) (avc1 / 0x31637661), yuv420p(progressive), 1920x1080 [SAR 1:1 DAR 16:9], 9354 kb/s, 30 fps, 30 tbr, 30k tbn (default)
#     Metadata:
#       creation_time   : 2023-04-07T08:54:28.000000Z
#       handler_name    : ?Mainconcept Video Media Handler
#       vendor_id       : [0][0][0][0]
#       encoder         : AVC Coding
#   Stream #0:1[0x2](eng): Audio: aac (LC) (mp4a / 0x6134706D), 48000 Hz, stereo, fltp, 317 kb/s (default)
#     Metadata:
#       creation_time   : 2023-04-07T08:54:28.000000Z
#       handler_name    : #Mainconcept MP4 Sound Media Handler
#       vendor_id       : [0][0][0][0]
# Stream mapping:
#   Stream #0:0 -> #0:0 (h264 (native) -> png (native))
# Press [q] to stop, [?] for help
# [swscaler @ 0x1288c8000] [swscaler @ 0x108008000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x1288c8000] [swscaler @ 0x108018000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x1288c8000] [swscaler @ 0x108028000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x1288c8000] [swscaler @ 0x108038000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x1288c8000] [swscaler @ 0x108048000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x1288c8000] [swscaler @ 0x108058000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x1288c8000] [swscaler @ 0x108068000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x1288c8000] [swscaler @ 0x108078000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x1288c8000] [swscaler @ 0x108088000] No accelerated colorspace conversion found from yuv420p to rgb24.
# Output #0, image2, to 'dataset_train/vimizer/3/img_%05d.png':
#   Metadata:
#     major_brand     : mp42
#     minor_version   : 0
#     compatible_brands: mp42mp41
#     encoder         : Lavf60.3.100
#   Stream #0:0(eng): Video: png, rgb24(pc, gbr/unknown/unknown, progressive), 1920x1080 [SAR 1:1 DAR 16:9], q=2-31, 200 kb/s, 30 fps, 30 tbn (default)
#     Metadata:
#       creation_time   : 2023-04-07T08:54:28.000000Z
#       handler_name    : ?Mainconcept Video Media Handler
#       vendor_id       : [0][0][0][0]
#       encoder         : Lavc60.3.100 png
# frame=   20 fps=0.0 q=-0.0 Lsize=N/A time=00:00:19.00 bitrate=N/A speed=35.1x    ts/s speed=N/A
# video:28688kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: unknown
# ffmpeg version 6.0 Copyright (c) 2000-2023 the FFmpeg developers
#   built with Apple clang version 15.0.0 (clang-1500.0.40.1)
#   configuration: --prefix=/opt/homebrew/Cellar/ffmpeg/6.0_1 --enable-shared --enable-pthreads --enable-version3 --cc=clang --host-cflags= --host-ldflags='-Wl,-ld_classic' --enable-ffplay --enable-gnutls --enable-gpl --enable-libaom --enable-libaribb24 --enable-libbluray --enable-libdav1d --enable-libjxl --enable-libmp3lame --enable-libopus --enable-librav1e --enable-librist --enable-librubberband --enable-libsnappy --enable-libsrt --enable-libsvtav1 --enable-libtesseract --enable-libtheora --enable-libvidstab --enable-libvmaf --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxml2 --enable-libxvid --enable-lzma --enable-libfontconfig --enable-libfreetype --enable-frei0r --enable-libass --enable-libopencore-amrnb --enable-libopencore-amrwb --enable-libopenjpeg --enable-libspeex --enable-libsoxr --enable-libzmq --enable-libzimg --disable-libjack --disable-indev=jack --enable-videotoolbox --enable-audiotoolbox --enable-neon
#   libavutil      58.  2.100 / 58.  2.100
#   libavcodec     60.  3.100 / 60.  3.100
#   libavformat    60.  3.100 / 60.  3.100
#   libavdevice    60.  1.100 / 60.  1.100
#   libavfilter     9.  3.100 /  9.  3.100
#   libswscale      7.  1.100 /  7.  1.100
#   libswresample   4. 10.100 /  4. 10.100
#   libpostproc    57.  1.100 / 57.  1.100
# -vsync is deprecated. Use -fps_mode
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from 'dataset_video/vimizer/1.mp4':
#   Metadata:
#     major_brand     : mp42
#     minor_version   : 0
#     compatible_brands: mp42isomavc1
#     creation_time   : 2022-12-22T11:17:42.000000Z
#   Duration: 00:00:47.68, start: 0.000000, bitrate: 4014 kb/s
#   Stream #0:0[0x1](und): Video: h264 (High) (avc1 / 0x31637661), yuv420p(tv, bt709, progressive), 1920x1080, 3821 kb/s, 30 fps, 30 tbr, 30 tbn (default)
#     Metadata:
#       creation_time   : 2022-12-22T11:17:42.000000Z
#       handler_name    : Vimeo Artax Video Handler
#       vendor_id       : [0][0][0][0]
#       encoder         : AVC Coding
#   Stream #0:1[0x2](und): Audio: aac (LC) (mp4a / 0x6134706D), 48000 Hz, stereo, fltp, 189 kb/s (default)
#     Metadata:
#       creation_time   : 2022-12-22T11:17:42.000000Z
#       handler_name    : Vimeo Artax Audio Handler
#       vendor_id       : [0][0][0][0]
# Stream mapping:
#   Stream #0:0 -> #0:0 (h264 (native) -> png (native))
# Press [q] to stop, [?] for help
# [swscaler @ 0x148058000] [swscaler @ 0x1284f0000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x148058000] [swscaler @ 0x1284d8000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x148058000] [swscaler @ 0x128e38000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x148058000] [swscaler @ 0x128e48000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x148058000] [swscaler @ 0x128e58000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x148058000] [swscaler @ 0x128e68000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x148058000] [swscaler @ 0x128e78000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x148058000] [swscaler @ 0x128e88000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x148058000] [swscaler @ 0x128e98000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x128e98000] [swscaler @ 0x1284d8000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x128e98000] [swscaler @ 0x1284e8000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x128e98000] [swscaler @ 0x128e38000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x128e98000] [swscaler @ 0x128e48000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x128e98000] [swscaler @ 0x128e58000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x128e98000] [swscaler @ 0x128e68000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x128e98000] [swscaler @ 0x128e78000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x128e98000] [swscaler @ 0x128e88000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x128e98000] [swscaler @ 0x128ea8000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x128e98000] [swscaler @ 0x138400000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x128e98000] [swscaler @ 0x1383f0000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x128e98000] [swscaler @ 0x1380b0000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x128e98000] [swscaler @ 0x1380c0000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x128e98000] [swscaler @ 0x1380d0000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x128e98000] [swscaler @ 0x1380e0000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x128e98000] [swscaler @ 0x1380f0000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x128e98000] [swscaler @ 0x138100000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x128e98000] [swscaler @ 0x138110000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x148058000] [swscaler @ 0x138110000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x148058000] [swscaler @ 0x1383f0000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x148058000] [swscaler @ 0x138400000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x148058000] [swscaler @ 0x1380b0000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x148058000] [swscaler @ 0x1380c0000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x148058000] [swscaler @ 0x1380d0000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x148058000] [swscaler @ 0x1380e0000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x148058000] [swscaler @ 0x1380f0000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x148058000] [swscaler @ 0x138100000] No accelerated colorspace conversion found from yuv420p to rgb24.
# Output #0, image2, to 'dataset_train/vimizer/4/img_%05d.png':
#   Metadata:
#     major_brand     : mp42
#     minor_version   : 0
#     compatible_brands: mp42isomavc1
#     encoder         : Lavf60.3.100
#   Stream #0:0(und): Video: png, rgb24(pc, gbr/bt709/bt709, progressive), 1920x1080, q=2-31, 200 kb/s, 30 fps, 30 tbn (default)
#     Metadata:
#       creation_time   : 2022-12-22T11:17:42.000000Z
#       handler_name    : Vimeo Artax Video Handler
#       vendor_id       : [0][0][0][0]
#       encoder         : Lavc60.3.100 png
# frame=   18 fps=0.0 q=-0.0 Lsize=N/A time=00:00:45.46 bitrate=N/A speed=  70x    ts/s speed=N/A
# video:16935kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: unknown
# ffmpeg version 6.0 Copyright (c) 2000-2023 the FFmpeg developers
#   built with Apple clang version 15.0.0 (clang-1500.0.40.1)
#   configuration: --prefix=/opt/homebrew/Cellar/ffmpeg/6.0_1 --enable-shared --enable-pthreads --enable-version3 --cc=clang --host-cflags= --host-ldflags='-Wl,-ld_classic' --enable-ffplay --enable-gnutls --enable-gpl --enable-libaom --enable-libaribb24 --enable-libbluray --enable-libdav1d --enable-libjxl --enable-libmp3lame --enable-libopus --enable-librav1e --enable-librist --enable-librubberband --enable-libsnappy --enable-libsrt --enable-libsvtav1 --enable-libtesseract --enable-libtheora --enable-libvidstab --enable-libvmaf --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxml2 --enable-libxvid --enable-lzma --enable-libfontconfig --enable-libfreetype --enable-frei0r --enable-libass --enable-libopencore-amrnb --enable-libopencore-amrwb --enable-libopenjpeg --enable-libspeex --enable-libsoxr --enable-libzmq --enable-libzimg --disable-libjack --disable-indev=jack --enable-videotoolbox --enable-audiotoolbox --enable-neon
#   libavutil      58.  2.100 / 58.  2.100
#   libavcodec     60.  3.100 / 60.  3.100
#   libavformat    60.  3.100 / 60.  3.100
#   libavdevice    60.  1.100 / 60.  1.100
#   libavfilter     9.  3.100 /  9.  3.100
#   libswscale      7.  1.100 /  7.  1.100
#   libswresample   4. 10.100 /  4. 10.100
#   libpostproc    57.  1.100 / 57.  1.100
# -vsync is deprecated. Use -fps_mode
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from 'dataset_video/vimizer/0.mp4':
#   Metadata:
#     major_brand     : mp42
#     minor_version   : 0
#     compatible_brands: mp42mp41
#     creation_time   : 2023-03-07T16:13:26.000000Z
#   Duration: 00:00:15.00, start: 0.000000, bitrate: 13062 kb/s
#   Stream #0:0[0x1](eng): Video: h264 (Main) (avc1 / 0x31637661), yuv420p(progressive), 1920x1080 [SAR 1:1 DAR 16:9], 12634 kb/s, 24 fps, 24 tbr, 24k tbn (default)
#     Metadata:
#       creation_time   : 2023-03-07T16:13:26.000000Z
#       handler_name    : ?Mainconcept Video Media Handler
#       vendor_id       : [0][0][0][0]
#       encoder         : AVC Coding
#   Stream #0:1[0x2](eng): Audio: aac (LC) (mp4a / 0x6134706D), 48000 Hz, stereo, fltp, 317 kb/s (default)
#     Metadata:
#       creation_time   : 2023-03-07T16:13:26.000000Z
#       handler_name    : #Mainconcept MP4 Sound Media Handler
#       vendor_id       : [0][0][0][0]
# Stream mapping:
#   Stream #0:0 -> #0:0 (h264 (native) -> png (native))
# Press [q] to stop, [?] for help
# [swscaler @ 0x120520000] [swscaler @ 0x120530000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x120520000] [swscaler @ 0x120540000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x120520000] [swscaler @ 0x120550000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x120520000] [swscaler @ 0x120560000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x120520000] [swscaler @ 0x120570000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x120520000] [swscaler @ 0x120580000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x120520000] [swscaler @ 0x120590000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x120520000] [swscaler @ 0x1205a0000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x120520000] [swscaler @ 0x1205b0000] No accelerated colorspace conversion found from yuv420p to rgb24.
# Output #0, image2, to 'dataset_train/vimizer/5/img_%05d.png':
#   Metadata:
#     major_brand     : mp42
#     minor_version   : 0
#     compatible_brands: mp42mp41
#     encoder         : Lavf60.3.100
#   Stream #0:0(eng): Video: png, rgb24(pc, gbr/unknown/unknown, progressive), 1920x1080 [SAR 1:1 DAR 16:9], q=2-31, 200 kb/s, 24 fps, 24 tbn (default)
#     Metadata:
#       creation_time   : 2023-03-07T16:13:26.000000Z
#       handler_name    : ?Mainconcept Video Media Handler
#       vendor_id       : [0][0][0][0]
#       encoder         : Lavc60.3.100 png
# frame=   12 fps=0.0 q=-0.0 Lsize=N/A time=00:00:13.75 bitrate=N/A speed=32.8x    ts/s speed=N/A
# video:19083kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: unknown
# ffmpeg version 6.0 Copyright (c) 2000-2023 the FFmpeg developers
#   built with Apple clang version 15.0.0 (clang-1500.0.40.1)
#   configuration: --prefix=/opt/homebrew/Cellar/ffmpeg/6.0_1 --enable-shared --enable-pthreads --enable-version3 --cc=clang --host-cflags= --host-ldflags='-Wl,-ld_classic' --enable-ffplay --enable-gnutls --enable-gpl --enable-libaom --enable-libaribb24 --enable-libbluray --enable-libdav1d --enable-libjxl --enable-libmp3lame --enable-libopus --enable-librav1e --enable-librist --enable-librubberband --enable-libsnappy --enable-libsrt --enable-libsvtav1 --enable-libtesseract --enable-libtheora --enable-libvidstab --enable-libvmaf --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxml2 --enable-libxvid --enable-lzma --enable-libfontconfig --enable-libfreetype --enable-frei0r --enable-libass --enable-libopencore-amrnb --enable-libopencore-amrwb --enable-libopenjpeg --enable-libspeex --enable-libsoxr --enable-libzmq --enable-libzimg --disable-libjack --disable-indev=jack --enable-videotoolbox --enable-audiotoolbox --enable-neon
#   libavutil      58.  2.100 / 58.  2.100
#   libavcodec     60.  3.100 / 60.  3.100
#   libavformat    60.  3.100 / 60.  3.100
#   libavdevice    60.  1.100 / 60.  1.100
#   libavfilter     9.  3.100 /  9.  3.100
#   libswscale      7.  1.100 /  7.  1.100
#   libswresample   4. 10.100 /  4. 10.100
#   libpostproc    57.  1.100 / 57.  1.100
# -vsync is deprecated. Use -fps_mode
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from 'dataset_video/vimizer/2.mp4':
#   Metadata:
#     major_brand     : mp42
#     minor_version   : 0
#     compatible_brands: mp42mp41
#     creation_time   : 2023-07-20T08:24:36.000000Z
#   Duration: 00:00:20.00, start: 0.000000, bitrate: 9667 kb/s
#   Stream #0:0[0x1](eng): Video: h264 (Main) (avc1 / 0x31637661), yuv420p(tv, bt709, progressive), 1920x1080, 9325 kb/s, 25 fps, 25 tbr, 25k tbn (default)
#     Metadata:
#       creation_time   : 2023-07-20T08:24:36.000000Z
#       handler_name    : ?Mainconcept Video Media Handler
#       vendor_id       : [0][0][0][0]
#       encoder         : AVC Coding
#   Stream #0:1[0x2](eng): Audio: aac (LC) (mp4a / 0x6134706D), 48000 Hz, stereo, fltp, 317 kb/s (default)
#     Metadata:
#       creation_time   : 2023-07-20T08:24:37.000000Z
#       handler_name    : #Mainconcept MP4 Sound Media Handler
#       vendor_id       : [0][0][0][0]
# Stream mapping:
#   Stream #0:0 -> #0:0 (h264 (native) -> png (native))
# Press [q] to stop, [?] for help
# [swscaler @ 0x138710000] [swscaler @ 0x138720000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x138710000] [swscaler @ 0x138730000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x138710000] [swscaler @ 0x138740000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x138710000] [swscaler @ 0x138750000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x138710000] [swscaler @ 0x138760000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x138710000] [swscaler @ 0x138770000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x138710000] [swscaler @ 0x138780000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x138710000] [swscaler @ 0x138790000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x138710000] [swscaler @ 0x1387a0000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x148860000] [swscaler @ 0x149170000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x148860000] [swscaler @ 0x149180000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x148860000] [swscaler @ 0x148250000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x148860000] [swscaler @ 0x148260000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x148860000] [swscaler @ 0x148270000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x148860000] [swscaler @ 0x148ee0000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x148860000] [swscaler @ 0x148ef0000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x148860000] [swscaler @ 0x148f00000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x148860000] [swscaler @ 0x148f10000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x138710000] [swscaler @ 0x148860000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x138710000] [swscaler @ 0x149170000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x138710000] [swscaler @ 0x149180000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x138710000] [swscaler @ 0x148250000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x138710000] [swscaler @ 0x148260000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x138710000] [swscaler @ 0x148270000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x138710000] [swscaler @ 0x148ee0000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x138710000] [swscaler @ 0x148ef0000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x138710000] [swscaler @ 0x148f00000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x138710000] [swscaler @ 0x138198000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x138710000] [swscaler @ 0x1381a8000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x138710000] [swscaler @ 0x1381b8000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x138710000] [swscaler @ 0x1381c8000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x138710000] [swscaler @ 0x1381d8000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x138710000] [swscaler @ 0x138720000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x138710000] [swscaler @ 0x138730000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x138710000] [swscaler @ 0x138740000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x138710000] [swscaler @ 0x138750000] No accelerated colorspace conversion found from yuv420p to rgb24.
# Output #0, image2, to 'dataset_train/vimizer/6/img_%05d.png':
#   Metadata:
#     major_brand     : mp42
#     minor_version   : 0
#     compatible_brands: mp42mp41
#     encoder         : Lavf60.3.100
#   Stream #0:0(eng): Video: png, rgb24(pc, gbr/bt709/bt709, progressive), 1920x1080, q=2-31, 200 kb/s, 25 fps, 25 tbn (default)
#     Metadata:
#       creation_time   : 2023-07-20T08:24:36.000000Z
#       handler_name    : ?Mainconcept Video Media Handler
#       vendor_id       : [0][0][0][0]
#       encoder         : Lavc60.3.100 png
# frame=   10 fps=0.0 q=-0.0 Lsize=N/A time=00:00:18.04 bitrate=N/A speed=60.9x    ts/s speed=N/A
# video:12270kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: unknown
# ffmpeg version 6.0 Copyright (c) 2000-2023 the FFmpeg developers
#   built with Apple clang version 15.0.0 (clang-1500.0.40.1)
#   configuration: --prefix=/opt/homebrew/Cellar/ffmpeg/6.0_1 --enable-shared --enable-pthreads --enable-version3 --cc=clang --host-cflags= --host-ldflags='-Wl,-ld_classic' --enable-ffplay --enable-gnutls --enable-gpl --enable-libaom --enable-libaribb24 --enable-libbluray --enable-libdav1d --enable-libjxl --enable-libmp3lame --enable-libopus --enable-librav1e --enable-librist --enable-librubberband --enable-libsnappy --enable-libsrt --enable-libsvtav1 --enable-libtesseract --enable-libtheora --enable-libvidstab --enable-libvmaf --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxml2 --enable-libxvid --enable-lzma --enable-libfontconfig --enable-libfreetype --enable-frei0r --enable-libass --enable-libopencore-amrnb --enable-libopencore-amrwb --enable-libopenjpeg --enable-libspeex --enable-libsoxr --enable-libzmq --enable-libzimg --disable-libjack --disable-indev=jack --enable-videotoolbox --enable-audiotoolbox --enable-neon
#   libavutil      58.  2.100 / 58.  2.100
#   libavcodec     60.  3.100 / 60.  3.100
#   libavformat    60.  3.100 / 60.  3.100
#   libavdevice    60.  1.100 / 60.  1.100
#   libavfilter     9.  3.100 /  9.  3.100
#   libswscale      7.  1.100 /  7.  1.100
#   libswresample   4. 10.100 /  4. 10.100
#   libpostproc    57.  1.100 / 57.  1.100
# -vsync is deprecated. Use -fps_mode
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from 'dataset_video/vimizer/3.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf58.76.100
#   Duration: 00:00:15.04, start: 0.000000, bitrate: 12831 kb/s
#   Stream #0:0[0x1](und): Video: h264 (High) (avc1 / 0x31637661), yuv420p(tv, bt709, progressive), 1920x1080, 12489 kb/s, 25 fps, 25 tbr, 12800 tbn (default)
#     Metadata:
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
#       timecode        : 00:00:00:00
#   Stream #0:1[0x2](und): Audio: aac (LC) (mp4a / 0x6134706D), 48000 Hz, stereo, fltp, 368 kb/s (default)
#     Metadata:
#       handler_name    : SoundHandler
#       vendor_id       : [0][0][0][0]
#   Stream #0:2[0x3](eng): Data: none (tmcd / 0x64636D74), 0 kb/s
#     Metadata:
#       handler_name    : VideoHandler
#       timecode        : 00:00:00:00
# Stream mapping:
#   Stream #0:0 -> #0:0 (h264 (native) -> png (native))
# Press [q] to stop, [?] for help
# [swscaler @ 0x110018000] [swscaler @ 0x110028000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x110018000] [swscaler @ 0x110038000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x110018000] [swscaler @ 0x110048000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x110018000] [swscaler @ 0x110058000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x110018000] [swscaler @ 0x110068000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x110018000] [swscaler @ 0x110078000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x110018000] [swscaler @ 0x110088000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x110018000] [swscaler @ 0x110098000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x110018000] [swscaler @ 0x1100a8000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x140490000] [swscaler @ 0x140398000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x140490000] [swscaler @ 0x1404d8000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x140490000] [swscaler @ 0x1404e8000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x140490000] [swscaler @ 0x140118000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x140490000] [swscaler @ 0x140128000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x140490000] [swscaler @ 0x140138000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x140490000] [swscaler @ 0x1401c0000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x140490000] [swscaler @ 0x1401d0000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x140490000] [swscaler @ 0x1401e0000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x140490000] [swscaler @ 0x110018000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x140490000] [swscaler @ 0x110028000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x140490000] [swscaler @ 0x110038000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x140490000] [swscaler @ 0x110048000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x140490000] [swscaler @ 0x110058000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x140490000] [swscaler @ 0x110068000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x140490000] [swscaler @ 0x110078000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x140490000] [swscaler @ 0x110088000] No accelerated colorspace conversion found from yuv420p to rgb24.
# ...
#   Stream #0:0(und): Video: png, rgb24(pc, gbr/bt709/bt709, progressive), 1024x576 [SAR 1:1 DAR 16:9], q=2-31, 200 kb/s, 25 fps, 25 tbn (default)
#     Metadata:
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
#       encoder         : Lavc60.3.100 png
# frame=    4 fps=0.0 q=-0.0 Lsize=N/A time=00:00:09.64 bitrate=N/A speed= 155x    ts/s speed=N/A
# video:2099kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: unknown
# ffmpeg version 6.0 Copyright (c) 2000-2023 the FFmpeg developers
#   built with Apple clang version 15.0.0 (clang-1500.0.40.1)
#   configuration: --prefix=/opt/homebrew/Cellar/ffmpeg/6.0_1 --enable-shared --enable-pthreads --enable-version3 --cc=clang --host-cflags= --host-ldflags='-Wl,-ld_classic' --enable-ffplay --enable-gnutls --enable-gpl --enable-libaom --enable-libaribb24 --enable-libbluray --enable-libdav1d --enable-libjxl --enable-libmp3lame --enable-libopus --enable-librav1e --enable-librist --enable-librubberband --enable-libsnappy --enable-libsrt --enable-libsvtav1 --enable-libtesseract --enable-libtheora --enable-libvidstab --enable-libvmaf --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxml2 --enable-libxvid --enable-lzma --enable-libfontconfig --enable-libfreetype --enable-frei0r --enable-libass --enable-libopencore-amrnb --enable-libopencore-amrwb --enable-libopenjpeg --enable-libspeex --enable-libsoxr --enable-libzmq --enable-libzimg --disable-libjack --disable-indev=jack --enable-videotoolbox --enable-audiotoolbox --enable-neon
#   libavutil      58.  2.100 / 58.  2.100
#   libavcodec     60.  3.100 / 60.  3.100
#   libavformat    60.  3.100 / 60.  3.100
#   libavdevice    60.  1.100 / 60.  1.100
#   libavfilter     9.  3.100 /  9.  3.100
#   libswscale      7.  1.100 /  7.  1.100
#   libswresample   4. 10.100 /  4. 10.100
#   libpostproc    57.  1.100 / 57.  1.100
# -vsync is deprecated. Use -fps_mode
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from 'dataset_video/tiktok/10.mp4':
#   Metadata:
#     minor_version   : 512
#     major_brand     : isom
#     compatible_brands: isomiso2avc1mp41
#     comment         : vid:v09025g40000clorgrvog65k5hpk3nfg
#     encoder         : Lavf58.20.100
#   Duration: 00:00:15.02, start: 0.000000, bitrate: 559 kb/s
#   Stream #0:0[0x1](und): Video: h264 (High) (avc1 / 0x31637661), yuv420p(progressive), 1024x576 [SAR 1:1 DAR 16:9], 487 kb/s, 25 fps, 25 tbr, 12800 tbn (default)
#     Metadata:
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
#   Stream #0:1[0x2](und): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 64 kb/s (default)
#     Metadata:
#       handler_name    : SoundHandler
#       vendor_id       : [0][0][0][0]
# Stream mapping:
#   Stream #0:0 -> #0:0 (h264 (native) -> png (native))
# Press [q] to stop, [?] for help
# [swscaler @ 0x120380000] [swscaler @ 0x120390000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x120380000] [swscaler @ 0x1203a0000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x120380000] [swscaler @ 0x1203b0000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x120380000] [swscaler @ 0x1203c0000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x120380000] [swscaler @ 0x1203d0000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x120380000] [swscaler @ 0x1203e0000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x120380000] [swscaler @ 0x1203f0000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x120380000] [swscaler @ 0x120400000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x120380000] [swscaler @ 0x120410000] No accelerated colorspace conversion found from yuv420p to rgb24.
# Output #0, image2, to 'dataset_train/tiktok/8/img_%05d.png':
#   Metadata:
#     minor_version   : 512
#     major_brand     : isom
#     compatible_brands: isomiso2avc1mp41
#     comment         : vid:v09025g40000clorgrvog65k5hpk3nfg
#     encoder         : Lavf60.3.100
#   Stream #0:0(und): Video: png, rgb24(pc, gbr/unknown/unknown, progressive), 1024x576 [SAR 1:1 DAR 16:9], q=2-31, 200 kb/s, 25 fps, 25 tbn (default)
#     Metadata:
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
#       encoder         : Lavc60.3.100 png
# frame=    2 fps=0.0 q=-0.0 Lsize=N/A time=00:00:10.00 bitrate=N/A speed= 251x    ts/s speed=N/A
# video:899kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: unknown
# ffmpeg version 6.0 Copyright (c) 2000-2023 the FFmpeg developers
#   built with Apple clang version 15.0.0 (clang-1500.0.40.1)
#   configuration: --prefix=/opt/homebrew/Cellar/ffmpeg/6.0_1 --enable-shared --enable-pthreads --enable-version3 --cc=clang --host-cflags= --host-ldflags='-Wl,-ld_classic' --enable-ffplay --enable-gnutls --enable-gpl --enable-libaom --enable-libaribb24 --enable-libbluray --enable-libdav1d --enable-libjxl --enable-libmp3lame --enable-libopus --enable-librav1e --enable-librist --enable-librubberband --enable-libsnappy --enable-libsrt --enable-libsvtav1 --enable-libtesseract --enable-libtheora --enable-libvidstab --enable-libvmaf --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxml2 --enable-libxvid --enable-lzma --enable-libfontconfig --enable-libfreetype --enable-frei0r --enable-libass --enable-libopencore-amrnb --enable-libopencore-amrwb --enable-libopenjpeg --enable-libspeex --enable-libsoxr --enable-libzmq --enable-libzimg --disable-libjack --disable-indev=jack --enable-videotoolbox --enable-audiotoolbox --enable-neon
#   libavutil      58.  2.100 / 58.  2.100
#   libavcodec     60.  3.100 / 60.  3.100
#   libavformat    60.  3.100 / 60.  3.100
#   libavdevice    60.  1.100 / 60.  1.100
#   libavfilter     9.  3.100 /  9.  3.100
#   libswscale      7.  1.100 /  7.  1.100
#   libswresample   4. 10.100 /  4. 10.100
#   libpostproc    57.  1.100 / 57.  1.100
# -vsync is deprecated. Use -fps_mode
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from 'dataset_video/tiktok/8.mp4':
#   Metadata:
#     minor_version   : 512
#     major_brand     : isom
#     compatible_brands: isomiso2avc1mp41
#     comment         : vid:v09025g40000clorg2fog65si1pum0e0
#     encoder         : Lavf58.20.100
#   Duration: 00:00:15.02, start: 0.000000, bitrate: 564 kb/s
#   Stream #0:0[0x1](und): Video: h264 (High) (avc1 / 0x31637661), yuv420p(tv, bt709, progressive), 1024x576 [SAR 1:1 DAR 16:9], 493 kb/s, 25 fps, 25 tbr, 12800 tbn (default)
#     Metadata:
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
#   Stream #0:1[0x2](und): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 64 kb/s (default)
#     Metadata:
#       handler_name    : SoundHandler
#       vendor_id       : [0][0][0][0]
# Stream mapping:
#   Stream #0:0 -> #0:0 (h264 (native) -> png (native))
# Press [q] to stop, [?] for help
# [swscaler @ 0x1384e0000] [swscaler @ 0x1384f0000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x1384e0000] [swscaler @ 0x138500000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x1384e0000] [swscaler @ 0x138510000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x1384e0000] [swscaler @ 0x138520000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x1384e0000] [swscaler @ 0x138530000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x1384e0000] [swscaler @ 0x138540000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x1384e0000] [swscaler @ 0x138550000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x1384e0000] [swscaler @ 0x138560000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x1384e0000] [swscaler @ 0x138570000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x1384e0000] [swscaler @ 0x138108000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x1384e0000] [swscaler @ 0x138118000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x1384e0000] [swscaler @ 0x138128000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x1384e0000] [swscaler @ 0x138138000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x1384e0000] [swscaler @ 0x138148000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x1384e0000] [swscaler @ 0x138158000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x1384e0000] [swscaler @ 0x138168000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x1384e0000] [swscaler @ 0x138178000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x1384e0000] [swscaler @ 0x1384f0000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x128868000] [swscaler @ 0x128878000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x128868000] [swscaler @ 0x128888000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x128868000] [swscaler @ 0x128898000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x128868000] [swscaler @ 0x1287d0000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x128868000] [swscaler @ 0x1287e0000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x128868000] [swscaler @ 0x1287f0000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x128868000] [swscaler @ 0x128800000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x128868000] [swscaler @ 0x128938000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x128868000] [swscaler @ 0x128948000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x1183a0000] [swscaler @ 0x128868000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x1183a0000] [swscaler @ 0x128878000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x1183a0000] [swscaler @ 0x128888000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x1183a0000] [swscaler @ 0x128898000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x1183a0000] [swscaler @ 0x128938000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x1183a0000] [swscaler @ 0x128948000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x1183a0000] [swscaler @ 0x128958000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x1183a0000] [swscaler @ 0x128968000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x1183a0000] [swscaler @ 0x128788000] No accelerated colorspace conversion found from yuv420p to rgb24.
# Output #0, image2, to 'dataset_test/tiktok/9/img_%05d.png':
#   Metadata:
#     minor_version   : 512
#     major_brand     : isom
#     compatible_brands: isomiso2avc1mp41
#     comment         : vid:v09025g40000clorg2fog65si1pum0e0
#     encoder         : Lavf60.3.100
#   Stream #0:0(und): Video: png, rgb24(pc, gbr/bt709/bt709, progressive), 1024x576 [SAR 1:1 DAR 16:9], q=2-31, 200 kb/s, 25 fps, 25 tbn (default)
#     Metadata:
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
#       encoder         : Lavc60.3.100 png
# frame=    3 fps=0.0 q=-0.0 Lsize=N/A time=00:00:12.48 bitrate=N/A speed= 370x    ts/s speed=N/A
# video:425kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: unknown
# ffmpeg version 6.0 Copyright (c) 2000-2023 the FFmpeg developers
#   built with Apple clang version 15.0.0 (clang-1500.0.40.1)
#   configuration: --prefix=/opt/homebrew/Cellar/ffmpeg/6.0_1 --enable-shared --enable-pthreads --enable-version3 --cc=clang --host-cflags= --host-ldflags='-Wl,-ld_classic' --enable-ffplay --enable-gnutls --enable-gpl --enable-libaom --enable-libaribb24 --enable-libbluray --enable-libdav1d --enable-libjxl --enable-libmp3lame --enable-libopus --enable-librav1e --enable-librist --enable-librubberband --enable-libsnappy --enable-libsrt --enable-libsvtav1 --enable-libtesseract --enable-libtheora --enable-libvidstab --enable-libvmaf --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxml2 --enable-libxvid --enable-lzma --enable-libfontconfig --enable-libfreetype --enable-frei0r --enable-libass --enable-libopencore-amrnb --enable-libopencore-amrwb --enable-libopenjpeg --enable-libspeex --enable-libsoxr --enable-libzmq --enable-libzimg --disable-libjack --disable-indev=jack --enable-videotoolbox --enable-audiotoolbox --enable-neon
#   libavutil      58.  2.100 / 58.  2.100
#   libavcodec     60.  3.100 / 60.  3.100
#   libavformat    60.  3.100 / 60.  3.100
#   libavdevice    60.  1.100 / 60.  1.100
#   libavfilter     9.  3.100 /  9.  3.100
#   libswscale      7.  1.100 /  7.  1.100
#   libswresample   4. 10.100 /  4. 10.100
#   libpostproc    57.  1.100 / 57.  1.100
# -vsync is deprecated. Use -fps_mode
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from 'dataset_video/tiktok/9.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     comment         : vid:v09025g40000clorg8nog65ghqc0cun0
#     encoder         : Lavf58.76.100
#   Duration: 00:00:23.02, start: 0.000000, bitrate: 614 kb/s
#   Stream #0:0[0x1](und): Video: h264 (High) (avc1 / 0x31637661), yuv420p(progressive), 1024x576 [SAR 1:1 DAR 16:9], 577 kb/s, 25 fps, 25 tbr, 12800 tbn (default)
#     Metadata:
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
#   Stream #0:1[0x2](und): Audio: aac (HE-AACv2) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 32 kb/s (default)
#     Metadata:
#       handler_name    : SoundHandler
#       vendor_id       : [0][0][0][0]
# Stream mapping:
#   Stream #0:0 -> #0:0 (h264 (native) -> png (native))
# Press [q] to stop, [?] for help
# [swscaler @ 0x140d80000] [swscaler @ 0x140d90000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x140d80000] [swscaler @ 0x140da0000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x140d80000] [swscaler @ 0x140db0000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x140d80000] [swscaler @ 0x140dc0000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x140d80000] [swscaler @ 0x140dd0000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x140d80000] [swscaler @ 0x140de0000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x140d80000] [swscaler @ 0x140df0000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x140d80000] [swscaler @ 0x140e00000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x140d80000] [swscaler @ 0x140e10000] No accelerated colorspace conversion found from yuv420p to rgb24.
# Output #0, image2, to 'dataset_test/tiktok/10/img_%05d.png':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     comment         : vid:v09025g40000clorg8nog65ghqc0cun0
#     encoder         : Lavf60.3.100
#   Stream #0:0(und): Video: png, rgb24(pc, gbr/unknown/unknown, progressive), 1024x576 [SAR 1:1 DAR 16:9], q=2-31, 200 kb/s, 25 fps, 25 tbn (default)
#     Metadata:
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
#       encoder         : Lavc60.3.100 png
# frame=    6 fps=0.0 q=-0.0 Lsize=N/A time=00:00:19.20 bitrate=N/A speed= 424x    ts/s speed=N/A
# video:1338kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: unknown
