# %% [markdown]
# # DataLoader
# <p> Tutorial link: https://github.com/RaivoKoot/Video-Dataset-Loading-Pytorch or https://video-dataset-loading-pytorch.readthedocs.io/en/latest/ </p>

# %% [markdown]
# ## Database preparation
# <li> Input : 3 folders named ( tiktok, youtube, vimizer) which contains the mp4 videos  </li>
# <li> For each Folders : Create an homologue folder which contains num_videos folders. All of these folders named by the index of the video contain each frames of the same video. </li>
# <li> Annotations.txt file generation </li>
# <li> Extraction of I frames </li>

# %% [markdown]
# ### Creation of the architecture

# %%
### Useful Path ###
dataset_video= 'dataset_video'
dataset = './Database_3D/dataset_train'
dataset_test = './Database_3D/dataset_test'
nmbr_video_test=2

# %%
##### Librairies #####
import os
import cv2
import subprocess
import shutil

# %%
### Nettoyer la base de donnée ######
# remove all the folder of the database
shutil.rmtree(dataset)
shutil.rmtree(dataset_test)

# %%
####### Database creation ########
os.makedirs(dataset)
os.makedirs(dataset_test)
classe=-1

for folder in os.listdir(dataset_video):

    classe=classe+1
    folder_path = dataset + '/'+ folder
    folder_path_test = dataset_test + '/'+ folder
    os.makedirs(folder_path)
    os.makedirs(folder_path_test)

    print('creation of the folder ' + folder)

    folder_video_path = dataset_video + '/'+ folder


    for i, video in  enumerate(os.listdir(folder_video_path)) :

        if i < len(os.listdir(folder_video_path))- nmbr_video_test:
            video_path = folder_video_path + '/' + video
            output_folder_video_path = folder_path + '/' + str(i)

            # Creation of the frame folder for the video i 
            os.makedirs(output_folder_video_path)

            # Extraction of the frames in this folder
            # command = "ffmpeg -i " + video_path + " -vf fps=2 " + output_folder_video_path +"/img_%05d.png"
            # Extraction of the i frame -frame_pts true
            command = "ffmpeg -skip_frame nokey -i " + video_path + " -vsync vfr  " + output_folder_video_path +"/img_%05d.png"
            subprocess.run(command, shell=True)

            #Ajout de la ligne dans annotation.txt
            elements = os.listdir(output_folder_video_path)
            compteur= len(elements)
            

            with open('annotation.txt', 'a') as file:
                file.write(folder + '/' + str(i)+ " 1 " + str(compteur) + " " + str(classe) + "\n")
        
        else :
            video_path = folder_video_path + '/' + video
            output_folder_video_path = folder_path_test + '/' + str(i)

            # Creation of the frame folder for the video i 
            os.makedirs(output_folder_video_path)

            # Extraction of the frames in this folder
            # command = "ffmpeg -i " + video_path + " -vf fps=2 " + output_folder_video_path +"/img_%05d.png"
            # Extraction of the i frame 
            command = "ffmpeg -skip_frame nokey -i " + video_path + " -vsync vfr  " + output_folder_video_path +"/img_%05d.png"
            subprocess.run(command, shell=True)


            #Ajout de la ligne dans annotation.txt
            elements = os.listdir(output_folder_video_path)
            compteur= len(elements)
            

            with open('annotation_test.txt', 'a') as file:
                file.write(folder + '/' + str(i)+ " 1 " + str(compteur) + " " + str(classe) + "\n")
# Out:
# creation of the folder vimizer
# ffmpeg version 6.0 Copyright (c) 2000-2023 the FFmpeg developers
#   built with Apple clang version 15.0.0 (clang-1500.0.40.1)
#   configuration: --prefix=/opt/homebrew/Cellar/ffmpeg/6.0_1 --enable-shared --enable-pthreads --enable-version3 --cc=clang --host-cflags= --host-ldflags='-Wl,-ld_classic' --enable-ffplay --enable-gnutls --enable-gpl --enable-libaom --enable-libaribb24 --enable-libbluray --enable-libdav1d --enable-libjxl --enable-libmp3lame --enable-libopus --enable-librav1e --enable-librist --enable-librubberband --enable-libsnappy --enable-libsrt --enable-libsvtav1 --enable-libtesseract --enable-libtheora --enable-libvidstab --enable-libvmaf --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxml2 --enable-libxvid --enable-lzma --enable-libfontconfig --enable-libfreetype --enable-frei0r --enable-libass --enable-libopencore-amrnb --enable-libopencore-amrwb --enable-libopenjpeg --enable-libspeex --enable-libsoxr --enable-libzmq --enable-libzimg --disable-libjack --disable-indev=jack --enable-videotoolbox --enable-audiotoolbox --enable-neon
#   libavutil      58.  2.100 / 58.  2.100
#   libavcodec     60.  3.100 / 60.  3.100
#   libavformat    60.  3.100 / 60.  3.100
#   libavdevice    60.  1.100 / 60.  1.100
#   libavfilter     9.  3.100 /  9.  3.100
#   libswscale      7.  1.100 /  7.  1.100
#   libswresample   4. 10.100 /  4. 10.100
#   libpostproc    57.  1.100 / 57.  1.100
# -vsync is deprecated. Use -fps_mode
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from 'dataset_video/vimizer/7.mp4':
#   Metadata:
#     major_brand     : mp42
#     minor_version   : 0
#     compatible_brands: mp42mp41
#     creation_time   : 2023-04-12T09:04:07.000000Z
#   Duration: 00:00:20.00, start: 0.000000, bitrate: 9569 kb/s
#   Stream #0:0[0x1](eng): Video: h264 (High) (avc1 / 0x31637661), yuv420p(tv, bt709, progressive), 1920x1080 [SAR 1:1 DAR 16:9], 9226 kb/s, 25 fps, 25 tbr, 25k tbn (default)
#     Metadata:
#       creation_time   : 2023-04-12T09:04:07.000000Z
#       handler_name    : ?Mainconcept Video Media Handler
#       vendor_id       : [0][0][0][0]
#       encoder         : AVC Coding
#   Stream #0:1[0x2](eng): Audio: aac (LC) (mp4a / 0x6134706D), 48000 Hz, stereo, fltp, 317 kb/s (default)
#     Metadata:
#       creation_time   : 2023-04-12T09:04:07.000000Z
#       handler_name    : #Mainconcept MP4 Sound Media Handler
#       vendor_id       : [0][0][0][0]
# Stream mapping:
#   Stream #0:0 -> #0:0 (h264 (native) -> png (native))
# Press [q] to stop, [?] for help
# [swscaler @ 0x158a60000] [swscaler @ 0x148318000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x158a60000] [swscaler @ 0x148328000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x158a60000] [swscaler @ 0x148338000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x158a60000] [swscaler @ 0x148348000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x158a60000] [swscaler @ 0x148358000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x158a60000] [swscaler @ 0x148368000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x158a60000] [swscaler @ 0x148378000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x158a60000] [swscaler @ 0x148388000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x158a60000] [swscaler @ 0x148398000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x138728000] [swscaler @ 0x128348000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x138728000] [swscaler @ 0x128358000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x138728000] [swscaler @ 0x128368000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x138728000] [swscaler @ 0x128378000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x138728000] [swscaler @ 0x128388000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x138728000] [swscaler @ 0x128398000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x138728000] [swscaler @ 0x1283a8000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x138728000] [swscaler @ 0x1283b8000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x138728000] [swscaler @ 0x1283c8000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x158a60000] [swscaler @ 0x148398000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x158a60000] [swscaler @ 0x148318000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x158a60000] [swscaler @ 0x148328000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x158a60000] [swscaler @ 0x148338000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x158a60000] [swscaler @ 0x148348000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x158a60000] [swscaler @ 0x148358000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x158a60000] [swscaler @ 0x148368000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x158a60000] [swscaler @ 0x148378000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x158a60000] [swscaler @ 0x148388000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x148388000] [swscaler @ 0x148398000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x148388000] [swscaler @ 0x148318000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x148388000] [swscaler @ 0x148328000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x148388000] [swscaler @ 0x148338000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x148388000] [swscaler @ 0x148348000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x148388000] [swscaler @ 0x148358000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x148388000] [swscaler @ 0x148368000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x148388000] [swscaler @ 0x148378000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x148388000] [swscaler @ 0x1483a8000] No accelerated colorspace conversion found from yuv420p to rgb24.
# Output #0, image2, to './Database_3D/dataset_train/vimizer/0/img_%05d.png':
#   Metadata:
#     major_brand     : mp42
#     minor_version   : 0
#     compatible_brands: mp42mp41
#     encoder         : Lavf60.3.100
#   Stream #0:0(eng): Video: png, rgb24(pc, gbr/bt709/bt709, progressive), 1920x1080 [SAR 1:1 DAR 16:9], q=2-31, 200 kb/s, 25 fps, 25 tbn (default)
#     Metadata:
#       creation_time   : 2023-04-12T09:04:07.000000Z
#       handler_name    : ?Mainconcept Video Media Handler
#       vendor_id       : [0][0][0][0]
#       encoder         : Lavc60.3.100 png
# frame=   12 fps=0.0 q=-0.0 Lsize=N/A time=00:00:18.88 bitrate=N/A speed=30.7x    ts/s speed=N/A
# video:23518kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: unknown
# ffmpeg version 6.0 Copyright (c) 2000-2023 the FFmpeg developers
#   built with Apple clang version 15.0.0 (clang-1500.0.40.1)
#   configuration: --prefix=/opt/homebrew/Cellar/ffmpeg/6.0_1 --enable-shared --enable-pthreads --enable-version3 --cc=clang --host-cflags= --host-ldflags='-Wl,-ld_classic' --enable-ffplay --enable-gnutls --enable-gpl --enable-libaom --enable-libaribb24 --enable-libbluray --enable-libdav1d --enable-libjxl --enable-libmp3lame --enable-libopus --enable-librav1e --enable-librist --enable-librubberband --enable-libsnappy --enable-libsrt --enable-libsvtav1 --enable-libtesseract --enable-libtheora --enable-libvidstab --enable-libvmaf --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxml2 --enable-libxvid --enable-lzma --enable-libfontconfig --enable-libfreetype --enable-frei0r --enable-libass --enable-libopencore-amrnb --enable-libopencore-amrwb --enable-libopenjpeg --enable-libspeex --enable-libsoxr --enable-libzmq --enable-libzimg --disable-libjack --disable-indev=jack --enable-videotoolbox --enable-audiotoolbox --enable-neon
#   libavutil      58.  2.100 / 58.  2.100
#   libavcodec     60.  3.100 / 60.  3.100
#   libavformat    60.  3.100 / 60.  3.100
#   libavdevice    60.  1.100 / 60.  1.100
#   libavfilter     9.  3.100 /  9.  3.100
#   libswscale      7.  1.100 /  7.  1.100
#   libswresample   4. 10.100 /  4. 10.100
#   libpostproc    57.  1.100 / 57.  1.100
# -vsync is deprecated. Use -fps_mode
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from 'dataset_video/vimizer/6.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf60.3.100
#     comment         : Create videos with https://clipchamp.com/en/video-editor - free online video editor, video compressor, video converter.
#   Duration: 00:00:53.07, start: 0.000000, bitrate: 3604 kb/s
#   Stream #0:0[0x1](und): Video: h264 (High) (avc1 / 0x31637661), yuv420p(progressive), 1920x1080 [SAR 1:1 DAR 16:9], 3479 kb/s, 30 fps, 30 tbr, 15360 tbn (default)
#     Metadata:
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
#       encoder         : Lavc60.3.100 libx264
#   Stream #0:1[0x2](und): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 128 kb/s (default)
#     Metadata:
#       handler_name    : SoundHandler
#       vendor_id       : [0][0][0][0]
# Stream mapping:
#   Stream #0:0 -> #0:0 (h264 (native) -> png (native))
# Press [q] to stop, [?] for help
# [swscaler @ 0x140c98000] [swscaler @ 0x140ca8000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x140c98000] [swscaler @ 0x140cb8000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x140c98000] [swscaler @ 0x140cc8000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x140c98000] [swscaler @ 0x140cd8000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x140c98000] [swscaler @ 0x140ce8000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x140c98000] [swscaler @ 0x140cf8000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x140c98000] [swscaler @ 0x140d08000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x140c98000] [swscaler @ 0x140d18000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x140c98000] [swscaler @ 0x140d28000] No accelerated colorspace conversion found from yuv420p to rgb24.
# Output #0, image2, to './Database_3D/dataset_train/vimizer/1/img_%05d.png':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     comment         : Create videos with https://clipchamp.com/en/video-editor - free online video editor, video compressor, video converter.
#     encoder         : Lavf60.3.100
#   Stream #0:0(und): Video: png, rgb24(pc, gbr/unknown/unknown, progressive), 1920x1080 [SAR 1:1 DAR 16:9], q=2-31, 200 kb/s, 30 fps, 30 tbn (default)
#     Metadata:
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
#       encoder         : Lavc60.3.100 png
# frame=    7 fps=0.0 q=-0.0 Lsize=N/A time=00:00:47.83 bitrate=N/A speed= 115x    ts/s speed=N/A
# video:17044kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: unknown
# ffmpeg version 6.0 Copyright (c) 2000-2023 the FFmpeg developers
#   built with Apple clang version 15.0.0 (clang-1500.0.40.1)
#   configuration: --prefix=/opt/homebrew/Cellar/ffmpeg/6.0_1 --enable-shared --enable-pthreads --enable-version3 --cc=clang --host-cflags= --host-ldflags='-Wl,-ld_classic' --enable-ffplay --enable-gnutls --enable-gpl --enable-libaom --enable-libaribb24 --enable-libbluray --enable-libdav1d --enable-libjxl --enable-libmp3lame --enable-libopus --enable-librav1e --enable-librist --enable-librubberband --enable-libsnappy --enable-libsrt --enable-libsvtav1 --enable-libtesseract --enable-libtheora --enable-libvidstab --enable-libvmaf --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxml2 --enable-libxvid --enable-lzma --enable-libfontconfig --enable-libfreetype --enable-frei0r --enable-libass --enable-libopencore-amrnb --enable-libopencore-amrwb --enable-libopenjpeg --enable-libspeex --enable-libsoxr --enable-libzmq --enable-libzimg --disable-libjack --disable-indev=jack --enable-videotoolbox --enable-audiotoolbox --enable-neon
#   libavutil      58.  2.100 / 58.  2.100
#   libavcodec     60.  3.100 / 60.  3.100
#   libavformat    60.  3.100 / 60.  3.100
#   libavdevice    60.  1.100 / 60.  1.100
#   libavfilter     9.  3.100 /  9.  3.100
#   libswscale      7.  1.100 /  7.  1.100
#   libswresample   4. 10.100 /  4. 10.100
#   libpostproc    57.  1.100 / 57.  1.100
# -vsync is deprecated. Use -fps_mode
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from 'dataset_video/vimizer/4.mp4':
#   Metadata:
#     major_brand     : mp42
#     minor_version   : 0
#     compatible_brands: mp42mp41
#     creation_time   : 2023-07-03T15:18:23.000000Z
#   Duration: 00:00:20.00, start: 0.000000, bitrate: 9564 kb/s
#   Stream #0:0[0x1](eng): Video: h264 (Main) (avc1 / 0x31637661), yuv420p(tv, bt709, progressive), 1920x1080 [SAR 1:1 DAR 16:9], 9202 kb/s, 25 fps, 25 tbr, 25k tbn (default)
#     Metadata:
#       creation_time   : 2023-07-03T15:18:23.000000Z
#       handler_name    : ?Mainconcept Video Media Handler
#       vendor_id       : [0][0][0][0]
#       encoder         : AVC Coding
#   Stream #0:1[0x2](eng): Audio: aac (LC) (mp4a / 0x6134706D), 48000 Hz, stereo, fltp, 317 kb/s (default)
#     Metadata:
#       creation_time   : 2023-07-03T15:18:27.000000Z
#       handler_name    : #Mainconcept MP4 Sound Media Handler
#       vendor_id       : [0][0][0][0]
# Stream mapping:
#   Stream #0:0 -> #0:0 (h264 (native) -> png (native))
# Press [q] to stop, [?] for help
# [swscaler @ 0x128f00000] [swscaler @ 0x128f10000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x128f00000] [swscaler @ 0x128f20000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x128f00000] [swscaler @ 0x128f30000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x128f00000] [swscaler @ 0x128f40000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x128f00000] [swscaler @ 0x128f50000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x128f00000] [swscaler @ 0x128f60000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x128f00000] [swscaler @ 0x128f70000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x128f00000] [swscaler @ 0x128f80000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x128f00000] [swscaler @ 0x128f90000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x128f00000] [swscaler @ 0x1206c0000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x128f00000] [swscaler @ 0x1206d0000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x128f00000] [swscaler @ 0x1206e0000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x128f00000] [swscaler @ 0x1206f0000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x128f00000] [swscaler @ 0x120700000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x128f00000] [swscaler @ 0x120710000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x128f00000] [swscaler @ 0x120720000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x128f00000] [swscaler @ 0x120730000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x128f00000] [swscaler @ 0x120740000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x120740000] [swscaler @ 0x128f00000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x120740000] [swscaler @ 0x1281b0000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x120740000] [swscaler @ 0x1281c0000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x120740000] [swscaler @ 0x1281d0000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x120740000] [swscaler @ 0x128f10000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x120740000] [swscaler @ 0x128f20000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x120740000] [swscaler @ 0x128f30000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x120740000] [swscaler @ 0x128f40000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x120740000] [swscaler @ 0x128f50000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x128f50000] [swscaler @ 0x120740000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x128f50000] [swscaler @ 0x1206c0000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x128f50000] [swscaler @ 0x1206d0000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x128f50000] [swscaler @ 0x1206e0000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x128f50000] [swscaler @ 0x1206f0000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x128f50000] [swscaler @ 0x120700000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x128f50000] [swscaler @ 0x120710000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x128f50000] [swscaler @ 0x120720000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x128f50000] [swscaler @ 0x120730000] No accelerated colorspace conversion found from yuv420p to rgb24.
# Output #0, image2, to './Database_3D/dataset_train/vimizer/2/img_%05d.png':
#   Metadata:
#     major_brand     : mp42
#     minor_version   : 0
#     compatible_brands: mp42mp41
#     encoder         : Lavf60.3.100
#   Stream #0:0(eng): Video: png, rgb24(pc, gbr/bt709/bt709, progressive), 1920x1080 [SAR 1:1 DAR 16:9], q=2-31, 200 kb/s, 25 fps, 25 tbn (default)
#     Metadata:
#       creation_time   : 2023-07-03T15:18:23.000000Z
#       handler_name    : ?Mainconcept Video Media Handler
#       vendor_id       : [0][0][0][0]
#       encoder         : Lavc60.3.100 png
# frame=   13 fps=0.0 q=-0.0 Lsize=N/A time=00:00:18.88 bitrate=N/A speed=34.8x    ts/s speed=N/A
# video:22124kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: unknown
# ffmpeg version 6.0 Copyright (c) 2000-2023 the FFmpeg developers
#   built with Apple clang version 15.0.0 (clang-1500.0.40.1)
#   configuration: --prefix=/opt/homebrew/Cellar/ffmpeg/6.0_1 --enable-shared --enable-pthreads --enable-version3 --cc=clang --host-cflags= --host-ldflags='-Wl,-ld_classic' --enable-ffplay --enable-gnutls --enable-gpl --enable-libaom --enable-libaribb24 --enable-libbluray --enable-libdav1d --enable-libjxl --enable-libmp3lame --enable-libopus --enable-librav1e --enable-librist --enable-librubberband --enable-libsnappy --enable-libsrt --enable-libsvtav1 --enable-libtesseract --enable-libtheora --enable-libvidstab --enable-libvmaf --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxml2 --enable-libxvid --enable-lzma --enable-libfontconfig --enable-libfreetype --enable-frei0r --enable-libass --enable-libopencore-amrnb --enable-libopencore-amrwb --enable-libopenjpeg --enable-libspeex --enable-libsoxr --enable-libzmq --enable-libzimg --disable-libjack --disable-indev=jack --enable-videotoolbox --enable-audiotoolbox --enable-neon
#   libavutil      58.  2.100 / 58.  2.100
#   libavcodec     60.  3.100 / 60.  3.100
#   libavformat    60.  3.100 / 60.  3.100
#   libavdevice    60.  1.100 / 60.  1.100
#   libavfilter     9.  3.100 /  9.  3.100
#   libswscale      7.  1.100 /  7.  1.100
#   libswresample   4. 10.100 /  4. 10.100
#   libpostproc    57.  1.100 / 57.  1.100
# -vsync is deprecated. Use -fps_mode
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from 'dataset_video/vimizer/5.mp4':
#   Metadata:
#     major_brand     : mp42
#     minor_version   : 0
#     compatible_brands: mp42mp41
#     creation_time   : 2023-04-07T08:54:28.000000Z
#   Duration: 00:00:20.00, start: 0.000000, bitrate: 9695 kb/s
#   Stream #0:0[0x1](eng): Video: h264 (Main) (avc1 / 0x31637661), yuv420p(progressive), 1920x1080 [SAR 1:1 DAR 16:9], 9354 kb/s, 30 fps, 30 tbr, 30k tbn (default)
#     Metadata:
#       creation_time   : 2023-04-07T08:54:28.000000Z
#       handler_name    : ?Mainconcept Video Media Handler
#       vendor_id       : [0][0][0][0]
#       encoder         : AVC Coding
#   Stream #0:1[0x2](eng): Audio: aac (LC) (mp4a / 0x6134706D), 48000 Hz, stereo, fltp, 317 kb/s (default)
#     Metadata:
#       creation_time   : 2023-04-07T08:54:28.000000Z
#       handler_name    : #Mainconcept MP4 Sound Media Handler
#       vendor_id       : [0][0][0][0]
# Stream mapping:
#   Stream #0:0 -> #0:0 (h264 (native) -> png (native))
# Press [q] to stop, [?] for help
# [swscaler @ 0x138eb8000] [swscaler @ 0x138ec8000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x138eb8000] [swscaler @ 0x138ed8000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x138eb8000] [swscaler @ 0x138ee8000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x138eb8000] [swscaler @ 0x138ef8000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x138eb8000] [swscaler @ 0x138f08000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x138eb8000] [swscaler @ 0x138f18000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x138eb8000] [swscaler @ 0x138f28000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x138eb8000] [swscaler @ 0x138f38000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x138eb8000] [swscaler @ 0x138f48000] No accelerated colorspace conversion found from yuv420p to rgb24.
# Output #0, image2, to './Database_3D/dataset_train/vimizer/3/img_%05d.png':
#   Metadata:
#     major_brand     : mp42
#     minor_version   : 0
#     compatible_brands: mp42mp41
#     encoder         : Lavf60.3.100
#   Stream #0:0(eng): Video: png, rgb24(pc, gbr/unknown/unknown, progressive), 1920x1080 [SAR 1:1 DAR 16:9], q=2-31, 200 kb/s, 30 fps, 30 tbn (default)
#     Metadata:
#       creation_time   : 2023-04-07T08:54:28.000000Z
#       handler_name    : ?Mainconcept Video Media Handler
#       vendor_id       : [0][0][0][0]
#       encoder         : Lavc60.3.100 png
# frame=   20 fps=0.0 q=-0.0 Lsize=N/A time=00:00:19.00 bitrate=N/A speed=25.6x    ts/s speed=N/A
# video:28688kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: unknown
# ffmpeg version 6.0 Copyright (c) 2000-2023 the FFmpeg developers
#   built with Apple clang version 15.0.0 (clang-1500.0.40.1)
#   configuration: --prefix=/opt/homebrew/Cellar/ffmpeg/6.0_1 --enable-shared --enable-pthreads --enable-version3 --cc=clang --host-cflags= --host-ldflags='-Wl,-ld_classic' --enable-ffplay --enable-gnutls --enable-gpl --enable-libaom --enable-libaribb24 --enable-libbluray --enable-libdav1d --enable-libjxl --enable-libmp3lame --enable-libopus --enable-librav1e --enable-librist --enable-librubberband --enable-libsnappy --enable-libsrt --enable-libsvtav1 --enable-libtesseract --enable-libtheora --enable-libvidstab --enable-libvmaf --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxml2 --enable-libxvid --enable-lzma --enable-libfontconfig --enable-libfreetype --enable-frei0r --enable-libass --enable-libopencore-amrnb --enable-libopencore-amrwb --enable-libopenjpeg --enable-libspeex --enable-libsoxr --enable-libzmq --enable-libzimg --disable-libjack --disable-indev=jack --enable-videotoolbox --enable-audiotoolbox --enable-neon
#   libavutil      58.  2.100 / 58.  2.100
#   libavcodec     60.  3.100 / 60.  3.100
#   libavformat    60.  3.100 / 60.  3.100
#   libavdevice    60.  1.100 / 60.  1.100
#   libavfilter     9.  3.100 /  9.  3.100
#   libswscale      7.  1.100 /  7.  1.100
#   libswresample   4. 10.100 /  4. 10.100
#   libpostproc    57.  1.100 / 57.  1.100
# -vsync is deprecated. Use -fps_mode
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from 'dataset_video/vimizer/1.mp4':
#   Metadata:
#     major_brand     : mp42
#     minor_version   : 0
#     compatible_brands: mp42isomavc1
#     creation_time   : 2022-12-22T11:17:42.000000Z
#   Duration: 00:00:47.68, start: 0.000000, bitrate: 4014 kb/s
#   Stream #0:0[0x1](und): Video: h264 (High) (avc1 / 0x31637661), yuv420p(tv, bt709, progressive), 1920x1080, 3821 kb/s, 30 fps, 30 tbr, 30 tbn (default)
#     Metadata:
#       creation_time   : 2022-12-22T11:17:42.000000Z
#       handler_name    : Vimeo Artax Video Handler
#       vendor_id       : [0][0][0][0]
#       encoder         : AVC Coding
#   Stream #0:1[0x2](und): Audio: aac (LC) (mp4a / 0x6134706D), 48000 Hz, stereo, fltp, 189 kb/s (default)
#     Metadata:
#       creation_time   : 2022-12-22T11:17:42.000000Z
#       handler_name    : Vimeo Artax Audio Handler
#       vendor_id       : [0][0][0][0]
# Stream mapping:
#   Stream #0:0 -> #0:0 (h264 (native) -> png (native))
# Press [q] to stop, [?] for help
# [swscaler @ 0x128270000] [swscaler @ 0x118230000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x128270000] [swscaler @ 0x118220000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x128270000] [swscaler @ 0x118708000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x128270000] [swscaler @ 0x118020000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x128270000] [swscaler @ 0x118030000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x128270000] [swscaler @ 0x118040000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x128270000] [swscaler @ 0x118050000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x128270000] [swscaler @ 0x1190c8000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x128270000] [swscaler @ 0x1190d8000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x1087f8000] [swscaler @ 0x1190d8000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x1087f8000] [swscaler @ 0x1190c8000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x1087f8000] [swscaler @ 0x118708000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x1087f8000] [swscaler @ 0x118220000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x1087f8000] [swscaler @ 0x118230000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x1087f8000] [swscaler @ 0x118020000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x1087f8000] [swscaler @ 0x118030000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x1087f8000] [swscaler @ 0x118040000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x1087f8000] [swscaler @ 0x118050000] No accelerated colorspace conversion found from yuv420p to rgb24.
#     Last message repeated 1 times
# [swscaler @ 0x1087f8000] [swscaler @ 0x118708000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x1087f8000] [swscaler @ 0x118220000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x1087f8000] [swscaler @ 0x118230000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x1087f8000] [swscaler @ 0x1190c8000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x1087f8000] [swscaler @ 0x1190d8000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x1087f8000] [swscaler @ 0x118020000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x1087f8000] [swscaler @ 0x118030000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x1087f8000] [swscaler @ 0x118040000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x128270000] [swscaler @ 0x1087f8000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x128270000] [swscaler @ 0x108808000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x128270000] [swscaler @ 0x1087e0000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x128270000] [swscaler @ 0x108820000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x128270000] [swscaler @ 0x108830000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x128270000] [swscaler @ 0x108840000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x128270000] [swscaler @ 0x108850000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x128270000] [swscaler @ 0x108860000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x128270000] [swscaler @ 0x108870000] No accelerated colorspace conversion found from yuv420p to rgb24.
# Output #0, image2, to './Database_3D/dataset_train/vimizer/4/img_%05d.png':
#   Metadata:
#     major_brand     : mp42
#     minor_version   : 0
#     compatible_brands: mp42isomavc1
#     encoder         : Lavf60.3.100
#   Stream #0:0(und): Video: png, rgb24(pc, gbr/bt709/bt709, progressive), 1920x1080, q=2-31, 200 kb/s, 30 fps, 30 tbn (default)
#     Metadata:
#       creation_time   : 2022-12-22T11:17:42.000000Z
#       handler_name    : Vimeo Artax Video Handler
#       vendor_id       : [0][0][0][0]
#       encoder         : Lavc60.3.100 png
# frame=   18 fps= 18 q=-0.0 Lsize=N/A time=00:00:45.46 bitrate=N/A speed=45.4x    ts/s speed=N/A
# video:16935kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: unknown
# ffmpeg version 6.0 Copyright (c) 2000-2023 the FFmpeg developers
#   built with Apple clang version 15.0.0 (clang-1500.0.40.1)
#   configuration: --prefix=/opt/homebrew/Cellar/ffmpeg/6.0_1 --enable-shared --enable-pthreads --enable-version3 --cc=clang --host-cflags= --host-ldflags='-Wl,-ld_classic' --enable-ffplay --enable-gnutls --enable-gpl --enable-libaom --enable-libaribb24 --enable-libbluray --enable-libdav1d --enable-libjxl --enable-libmp3lame --enable-libopus --enable-librav1e --enable-librist --enable-librubberband --enable-libsnappy --enable-libsrt --enable-libsvtav1 --enable-libtesseract --enable-libtheora --enable-libvidstab --enable-libvmaf --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxml2 --enable-libxvid --enable-lzma --enable-libfontconfig --enable-libfreetype --enable-frei0r --enable-libass --enable-libopencore-amrnb --enable-libopencore-amrwb --enable-libopenjpeg --enable-libspeex --enable-libsoxr --enable-libzmq --enable-libzimg --disable-libjack --disable-indev=jack --enable-videotoolbox --enable-audiotoolbox --enable-neon
#   libavutil      58.  2.100 / 58.  2.100
#   libavcodec     60.  3.100 / 60.  3.100
#   libavformat    60.  3.100 / 60.  3.100
#   libavdevice    60.  1.100 / 60.  1.100
#   libavfilter     9.  3.100 /  9.  3.100
#   libswscale      7.  1.100 /  7.  1.100
#   libswresample   4. 10.100 /  4. 10.100
#   libpostproc    57.  1.100 / 57.  1.100
# -vsync is deprecated. Use -fps_mode
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from 'dataset_video/vimizer/0.mp4':
#   Metadata:
#     major_brand     : mp42
#     minor_version   : 0
#     compatible_brands: mp42mp41
#     creation_time   : 2023-03-07T16:13:26.000000Z
#   Duration: 00:00:15.00, start: 0.000000, bitrate: 13062 kb/s
#   Stream #0:0[0x1](eng): Video: h264 (Main) (avc1 / 0x31637661), yuv420p(progressive), 1920x1080 [SAR 1:1 DAR 16:9], 12634 kb/s, 24 fps, 24 tbr, 24k tbn (default)
#     Metadata:
#       creation_time   : 2023-03-07T16:13:26.000000Z
#       handler_name    : ?Mainconcept Video Media Handler
#       vendor_id       : [0][0][0][0]
#       encoder         : AVC Coding
#   Stream #0:1[0x2](eng): Audio: aac (LC) (mp4a / 0x6134706D), 48000 Hz, stereo, fltp, 317 kb/s (default)
#     Metadata:
#       creation_time   : 2023-03-07T16:13:26.000000Z
#       handler_name    : #Mainconcept MP4 Sound Media Handler
#       vendor_id       : [0][0][0][0]
# Stream mapping:
#   Stream #0:0 -> #0:0 (h264 (native) -> png (native))
# Press [q] to stop, [?] for help
# [swscaler @ 0x128d00000] [swscaler @ 0x138648000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x128d00000] [swscaler @ 0x138658000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x128d00000] [swscaler @ 0x138668000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x128d00000] [swscaler @ 0x138678000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x128d00000] [swscaler @ 0x138688000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x128d00000] [swscaler @ 0x138698000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x128d00000] [swscaler @ 0x1386a8000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x128d00000] [swscaler @ 0x1386b8000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x128d00000] [swscaler @ 0x1386c8000] No accelerated colorspace conversion found from yuv420p to rgb24.
# Output #0, image2, to './Database_3D/dataset_train/vimizer/5/img_%05d.png':
#   Metadata:
#     major_brand     : mp42
#     minor_version   : 0
#     compatible_brands: mp42mp41
#     encoder         : Lavf60.3.100
#   Stream #0:0(eng): Video: png, rgb24(pc, gbr/unknown/unknown, progressive), 1920x1080 [SAR 1:1 DAR 16:9], q=2-31, 200 kb/s, 24 fps, 24 tbn (default)
#     Metadata:
#       creation_time   : 2023-03-07T16:13:26.000000Z
#       handler_name    : ?Mainconcept Video Media Handler
#       vendor_id       : [0][0][0][0]
#       encoder         : Lavc60.3.100 png
# frame=   12 fps=0.0 q=-0.0 Lsize=N/A time=00:00:13.75 bitrate=N/A speed=20.8x    ts/s speed=N/A
# video:19083kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: unknown
# ffmpeg version 6.0 Copyright (c) 2000-2023 the FFmpeg developers
#   built with Apple clang version 15.0.0 (clang-1500.0.40.1)
#   configuration: --prefix=/opt/homebrew/Cellar/ffmpeg/6.0_1 --enable-shared --enable-pthreads --enable-version3 --cc=clang --host-cflags= --host-ldflags='-Wl,-ld_classic' --enable-ffplay --enable-gnutls --enable-gpl --enable-libaom --enable-libaribb24 --enable-libbluray --enable-libdav1d --enable-libjxl --enable-libmp3lame --enable-libopus --enable-librav1e --enable-librist --enable-librubberband --enable-libsnappy --enable-libsrt --enable-libsvtav1 --enable-libtesseract --enable-libtheora --enable-libvidstab --enable-libvmaf --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxml2 --enable-libxvid --enable-lzma --enable-libfontconfig --enable-libfreetype --enable-frei0r --enable-libass --enable-libopencore-amrnb --enable-libopencore-amrwb --enable-libopenjpeg --enable-libspeex --enable-libsoxr --enable-libzmq --enable-libzimg --disable-libjack --disable-indev=jack --enable-videotoolbox --enable-audiotoolbox --enable-neon
#   libavutil      58.  2.100 / 58.  2.100
#   libavcodec     60.  3.100 / 60.  3.100
#   libavformat    60.  3.100 / 60.  3.100
#   libavdevice    60.  1.100 / 60.  1.100
#   libavfilter     9.  3.100 /  9.  3.100
#   libswscale      7.  1.100 /  7.  1.100
#   libswresample   4. 10.100 /  4. 10.100
#   libpostproc    57.  1.100 / 57.  1.100
# -vsync is deprecated. Use -fps_mode
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from 'dataset_video/vimizer/2.mp4':
#   Metadata:
#     major_brand     : mp42
#     minor_version   : 0
#     compatible_brands: mp42mp41
#     creation_time   : 2023-07-20T08:24:36.000000Z
#   Duration: 00:00:20.00, start: 0.000000, bitrate: 9667 kb/s
#   Stream #0:0[0x1](eng): Video: h264 (Main) (avc1 / 0x31637661), yuv420p(tv, bt709, progressive), 1920x1080, 9325 kb/s, 25 fps, 25 tbr, 25k tbn (default)
#     Metadata:
#       creation_time   : 2023-07-20T08:24:36.000000Z
#       handler_name    : ?Mainconcept Video Media Handler
#       vendor_id       : [0][0][0][0]
#       encoder         : AVC Coding
#   Stream #0:1[0x2](eng): Audio: aac (LC) (mp4a / 0x6134706D), 48000 Hz, stereo, fltp, 317 kb/s (default)
#     Metadata:
#       creation_time   : 2023-07-20T08:24:37.000000Z
#       handler_name    : #Mainconcept MP4 Sound Media Handler
#       vendor_id       : [0][0][0][0]
# Stream mapping:
#   Stream #0:0 -> #0:0 (h264 (native) -> png (native))
# Press [q] to stop, [?] for help
# [swscaler @ 0x1407b8000] [swscaler @ 0x1501d0000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x1407b8000] [swscaler @ 0x1501a0000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x1407b8000] [swscaler @ 0x150700000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x1407b8000] [swscaler @ 0x150710000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x1407b8000] [swscaler @ 0x150670000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x1407b8000] [swscaler @ 0x150680000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x1407b8000] [swscaler @ 0x150690000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x1407b8000] [swscaler @ 0x1506a0000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x1407b8000] [swscaler @ 0x1506b0000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x1381b8000] [swscaler @ 0x1506b0000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x1381b8000] [swscaler @ 0x1501a0000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x1381b8000] [swscaler @ 0x1501c8000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x1381b8000] [swscaler @ 0x150700000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x1381b8000] [swscaler @ 0x150710000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x1381b8000] [swscaler @ 0x150670000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x1381b8000] [swscaler @ 0x150680000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x1381b8000] [swscaler @ 0x150690000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x1381b8000] [swscaler @ 0x1506a0000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x1381b8000] [swscaler @ 0x1381a8000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x1381b8000] [swscaler @ 0x138008000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x1381b8000] [swscaler @ 0x1381c8000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x1381b8000] [swscaler @ 0x138a18000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x1381b8000] [swscaler @ 0x138a28000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x1381b8000] [swscaler @ 0x138a38000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x1381b8000] [swscaler @ 0x138a48000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x1381b8000] [swscaler @ 0x138a58000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x1381b8000] [swscaler @ 0x138dc0000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x1506a0000] [swscaler @ 0x1381b8000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x1506a0000] [swscaler @ 0x1381c8000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x1506a0000] [swscaler @ 0x138008000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x1506a0000] [swscaler @ 0x1381a8000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x1506a0000] [swscaler @ 0x138a18000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x1506a0000] [swscaler @ 0x138a28000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x1506a0000] [swscaler @ 0x138a38000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x1506a0000] [swscaler @ 0x138a48000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x1506a0000] [swscaler @ 0x138a58000] No accelerated colorspace conversion found from yuv420p to rgb24.
# Output #0, image2, to './Database_3D/dataset_train/vimizer/6/img_%05d.png':
#   Metadata:
#     major_brand     : mp42
#     minor_version   : 0
#     compatible_brands: mp42mp41
#     encoder         : Lavf60.3.100
#   Stream #0:0(eng): Video: png, rgb24(pc, gbr/bt709/bt709, progressive), 1920x1080, q=2-31, 200 kb/s, 25 fps, 25 tbn (default)
#     Metadata:
#       creation_time   : 2023-07-20T08:24:36.000000Z
#       handler_name    : ?Mainconcept Video Media Handler
#       vendor_id       : [0][0][0][0]
#       encoder         : Lavc60.3.100 png
# frame=   10 fps=0.0 q=-0.0 Lsize=N/A time=00:00:18.04 bitrate=N/A speed=39.6x    ts/s speed=N/A
# video:12270kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: unknown
# ffmpeg version 6.0 Copyright (c) 2000-2023 the FFmpeg developers
#   built with Apple clang version 15.0.0 (clang-1500.0.40.1)
#   configuration: --prefix=/opt/homebrew/Cellar/ffmpeg/6.0_1 --enable-shared --enable-pthreads --enable-version3 --cc=clang --host-cflags= --host-ldflags='-Wl,-ld_classic' --enable-ffplay --enable-gnutls --enable-gpl --enable-libaom --enable-libaribb24 --enable-libbluray --enable-libdav1d --enable-libjxl --enable-libmp3lame --enable-libopus --enable-librav1e --enable-librist --enable-librubberband --enable-libsnappy --enable-libsrt --enable-libsvtav1 --enable-libtesseract --enable-libtheora --enable-libvidstab --enable-libvmaf --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxml2 --enable-libxvid --enable-lzma --enable-libfontconfig --enable-libfreetype --enable-frei0r --enable-libass --enable-libopencore-amrnb --enable-libopencore-amrwb --enable-libopenjpeg --enable-libspeex --enable-libsoxr --enable-libzmq --enable-libzimg --disable-libjack --disable-indev=jack --enable-videotoolbox --enable-audiotoolbox --enable-neon
#   libavutil      58.  2.100 / 58.  2.100
#   libavcodec     60.  3.100 / 60.  3.100
#   libavformat    60.  3.100 / 60.  3.100
#   libavdevice    60.  1.100 / 60.  1.100
#   libavfilter     9.  3.100 /  9.  3.100
#   libswscale      7.  1.100 /  7.  1.100
#   libswresample   4. 10.100 /  4. 10.100
#   libpostproc    57.  1.100 / 57.  1.100
# -vsync is deprecated. Use -fps_mode
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from 'dataset_video/vimizer/3.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf58.76.100
#   Duration: 00:00:15.04, start: 0.000000, bitrate: 12831 kb/s
#   Stream #0:0[0x1](und): Video: h264 (High) (avc1 / 0x31637661), yuv420p(tv, bt709, progressive), 1920x1080, 12489 kb/s, 25 fps, 25 tbr, 12800 tbn (default)
#     Metadata:
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
#       timecode        : 00:00:00:00
#   Stream #0:1[0x2](und): Audio: aac (LC) (mp4a / 0x6134706D), 48000 Hz, stereo, fltp, 368 kb/s (default)
#     Metadata:
#       handler_name    : SoundHandler
#       vendor_id       : [0][0][0][0]
#   Stream #0:2[0x3](eng): Data: none (tmcd / 0x64636D74), 0 kb/s
#     Metadata:
#       handler_name    : VideoHandler
#       timecode        : 00:00:00:00
# Stream mapping:
#   Stream #0:0 -> #0:0 (h264 (native) -> png (native))
# Press [q] to stop, [?] for help
# [swscaler @ 0x1186e0000] [swscaler @ 0x128e38000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x1186e0000] [swscaler @ 0x128a90000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x1186e0000] [swscaler @ 0x128d40000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x1186e0000] [swscaler @ 0x128840000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x1186e0000] [swscaler @ 0x128850000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x1186e0000] [swscaler @ 0x128860000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x1186e0000] [swscaler @ 0x129078000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x1186e0000] [swscaler @ 0x129088000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x1186e0000] [swscaler @ 0x129098000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x1186e0000] [swscaler @ 0x1186f0000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x1186e0000] [swscaler @ 0x118700000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x1186e0000] [swscaler @ 0x118760000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x1186e0000] [swscaler @ 0x118770000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x1186e0000] [swscaler @ 0x118780000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x1186e0000] [swscaler @ 0x118790000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x1186e0000] [swscaler @ 0x1187a0000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x1186e0000] [swscaler @ 0x1187b0000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x1186e0000] [swscaler @ 0x118800000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x129098000] [swscaler @ 0x128d40000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x129098000] [swscaler @ 0x128a90000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x129098000] [swscaler @ 0x1290a8000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x129098000] [swscaler @ 0x129078000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x129098000] [swscaler @ 0x129088000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x129098000] [swscaler @ 0x128e38000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x129098000] [swscaler @ 0x128e48000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x129098000] [swscaler @ 0x128840000] No accelerated colorspace conversion found from yuv420p to rgb24.
# ...
#     Metadata:
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
#       encoder         : Lavc60.3.100 png
# frame=    4 fps=0.0 q=-0.0 Lsize=N/A time=00:00:09.64 bitrate=N/A speed=93.3x    ts/s speed=N/A
# video:2099kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: unknown
# ffmpeg version 6.0 Copyright (c) 2000-2023 the FFmpeg developers
#   built with Apple clang version 15.0.0 (clang-1500.0.40.1)
#   configuration: --prefix=/opt/homebrew/Cellar/ffmpeg/6.0_1 --enable-shared --enable-pthreads --enable-version3 --cc=clang --host-cflags= --host-ldflags='-Wl,-ld_classic' --enable-ffplay --enable-gnutls --enable-gpl --enable-libaom --enable-libaribb24 --enable-libbluray --enable-libdav1d --enable-libjxl --enable-libmp3lame --enable-libopus --enable-librav1e --enable-librist --enable-librubberband --enable-libsnappy --enable-libsrt --enable-libsvtav1 --enable-libtesseract --enable-libtheora --enable-libvidstab --enable-libvmaf --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxml2 --enable-libxvid --enable-lzma --enable-libfontconfig --enable-libfreetype --enable-frei0r --enable-libass --enable-libopencore-amrnb --enable-libopencore-amrwb --enable-libopenjpeg --enable-libspeex --enable-libsoxr --enable-libzmq --enable-libzimg --disable-libjack --disable-indev=jack --enable-videotoolbox --enable-audiotoolbox --enable-neon
#   libavutil      58.  2.100 / 58.  2.100
#   libavcodec     60.  3.100 / 60.  3.100
#   libavformat    60.  3.100 / 60.  3.100
#   libavdevice    60.  1.100 / 60.  1.100
#   libavfilter     9.  3.100 /  9.  3.100
#   libswscale      7.  1.100 /  7.  1.100
#   libswresample   4. 10.100 /  4. 10.100
#   libpostproc    57.  1.100 / 57.  1.100
# -vsync is deprecated. Use -fps_mode
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from 'dataset_video/tiktok/10.mp4':
#   Metadata:
#     minor_version   : 512
#     major_brand     : isom
#     compatible_brands: isomiso2avc1mp41
#     comment         : vid:v09025g40000clorgrvog65k5hpk3nfg
#     encoder         : Lavf58.20.100
#   Duration: 00:00:15.02, start: 0.000000, bitrate: 559 kb/s
#   Stream #0:0[0x1](und): Video: h264 (High) (avc1 / 0x31637661), yuv420p(progressive), 1024x576 [SAR 1:1 DAR 16:9], 487 kb/s, 25 fps, 25 tbr, 12800 tbn (default)
#     Metadata:
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
#   Stream #0:1[0x2](und): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 64 kb/s (default)
#     Metadata:
#       handler_name    : SoundHandler
#       vendor_id       : [0][0][0][0]
# Stream mapping:
#   Stream #0:0 -> #0:0 (h264 (native) -> png (native))
# Press [q] to stop, [?] for help
# [swscaler @ 0x120228000] [swscaler @ 0x120238000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x120228000] [swscaler @ 0x120248000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x120228000] [swscaler @ 0x1203a0000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x120228000] [swscaler @ 0x1203b0000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x120228000] [swscaler @ 0x1203c0000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x120228000] [swscaler @ 0x1203d0000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x120228000] [swscaler @ 0x1203e0000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x120228000] [swscaler @ 0x1203f0000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x120228000] [swscaler @ 0x120400000] No accelerated colorspace conversion found from yuv420p to rgb24.
# Output #0, image2, to './Database_3D/dataset_train/tiktok/8/img_%05d.png':
#   Metadata:
#     minor_version   : 512
#     major_brand     : isom
#     compatible_brands: isomiso2avc1mp41
#     comment         : vid:v09025g40000clorgrvog65k5hpk3nfg
#     encoder         : Lavf60.3.100
#   Stream #0:0(und): Video: png, rgb24(pc, gbr/unknown/unknown, progressive), 1024x576 [SAR 1:1 DAR 16:9], q=2-31, 200 kb/s, 25 fps, 25 tbn (default)
#     Metadata:
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
#       encoder         : Lavc60.3.100 png
# frame=    2 fps=0.0 q=-0.0 Lsize=N/A time=00:00:10.00 bitrate=N/A speed= 148x    ts/s speed=N/A
# video:899kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: unknown
# ffmpeg version 6.0 Copyright (c) 2000-2023 the FFmpeg developers
#   built with Apple clang version 15.0.0 (clang-1500.0.40.1)
#   configuration: --prefix=/opt/homebrew/Cellar/ffmpeg/6.0_1 --enable-shared --enable-pthreads --enable-version3 --cc=clang --host-cflags= --host-ldflags='-Wl,-ld_classic' --enable-ffplay --enable-gnutls --enable-gpl --enable-libaom --enable-libaribb24 --enable-libbluray --enable-libdav1d --enable-libjxl --enable-libmp3lame --enable-libopus --enable-librav1e --enable-librist --enable-librubberband --enable-libsnappy --enable-libsrt --enable-libsvtav1 --enable-libtesseract --enable-libtheora --enable-libvidstab --enable-libvmaf --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxml2 --enable-libxvid --enable-lzma --enable-libfontconfig --enable-libfreetype --enable-frei0r --enable-libass --enable-libopencore-amrnb --enable-libopencore-amrwb --enable-libopenjpeg --enable-libspeex --enable-libsoxr --enable-libzmq --enable-libzimg --disable-libjack --disable-indev=jack --enable-videotoolbox --enable-audiotoolbox --enable-neon
#   libavutil      58.  2.100 / 58.  2.100
#   libavcodec     60.  3.100 / 60.  3.100
#   libavformat    60.  3.100 / 60.  3.100
#   libavdevice    60.  1.100 / 60.  1.100
#   libavfilter     9.  3.100 /  9.  3.100
#   libswscale      7.  1.100 /  7.  1.100
#   libswresample   4. 10.100 /  4. 10.100
#   libpostproc    57.  1.100 / 57.  1.100
# -vsync is deprecated. Use -fps_mode
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from 'dataset_video/tiktok/8.mp4':
#   Metadata:
#     minor_version   : 512
#     major_brand     : isom
#     compatible_brands: isomiso2avc1mp41
#     comment         : vid:v09025g40000clorg2fog65si1pum0e0
#     encoder         : Lavf58.20.100
#   Duration: 00:00:15.02, start: 0.000000, bitrate: 564 kb/s
#   Stream #0:0[0x1](und): Video: h264 (High) (avc1 / 0x31637661), yuv420p(tv, bt709, progressive), 1024x576 [SAR 1:1 DAR 16:9], 493 kb/s, 25 fps, 25 tbr, 12800 tbn (default)
#     Metadata:
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
#   Stream #0:1[0x2](und): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 64 kb/s (default)
#     Metadata:
#       handler_name    : SoundHandler
#       vendor_id       : [0][0][0][0]
# Stream mapping:
#   Stream #0:0 -> #0:0 (h264 (native) -> png (native))
# Press [q] to stop, [?] for help
# [swscaler @ 0x140ae0000] [swscaler @ 0x1204e8000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x140ae0000] [swscaler @ 0x1204f8000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x140ae0000] [swscaler @ 0x120508000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x140ae0000] [swscaler @ 0x120518000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x140ae0000] [swscaler @ 0x120528000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x140ae0000] [swscaler @ 0x120538000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x140ae0000] [swscaler @ 0x120548000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x140ae0000] [swscaler @ 0x120558000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x140ae0000] [swscaler @ 0x120568000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x110058000] [swscaler @ 0x120568000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x110058000] [swscaler @ 0x120008000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x110058000] [swscaler @ 0x120018000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x110058000] [swscaler @ 0x120028000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x110058000] [swscaler @ 0x120038000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x110058000] [swscaler @ 0x1204e8000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x110058000] [swscaler @ 0x1204f8000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x110058000] [swscaler @ 0x120508000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x110058000] [swscaler @ 0x120518000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x110058000] [swscaler @ 0x140ae0000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x110058000] [swscaler @ 0x140108000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x110058000] [swscaler @ 0x140118000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x110058000] [swscaler @ 0x140128000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x110058000] [swscaler @ 0x140138000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x110058000] [swscaler @ 0x140148000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x110058000] [swscaler @ 0x140158000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x110058000] [swscaler @ 0x140168000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x110058000] [swscaler @ 0x140178000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x120518000] [swscaler @ 0x1204e8000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x120518000] [swscaler @ 0x1204f8000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x120518000] [swscaler @ 0x120508000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x120518000] [swscaler @ 0x120008000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x120518000] [swscaler @ 0x120018000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x120518000] [swscaler @ 0x120028000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x120518000] [swscaler @ 0x120038000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x120518000] [swscaler @ 0x120528000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x120518000] [swscaler @ 0x120538000] No accelerated colorspace conversion found from yuv420p to rgb24.
# Output #0, image2, to './Database_3D/dataset_test/tiktok/9/img_%05d.png':
#   Metadata:
#     minor_version   : 512
#     major_brand     : isom
#     compatible_brands: isomiso2avc1mp41
#     comment         : vid:v09025g40000clorg2fog65si1pum0e0
#     encoder         : Lavf60.3.100
#   Stream #0:0(und): Video: png, rgb24(pc, gbr/bt709/bt709, progressive), 1024x576 [SAR 1:1 DAR 16:9], q=2-31, 200 kb/s, 25 fps, 25 tbn (default)
#     Metadata:
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
#       encoder         : Lavc60.3.100 png
# frame=    3 fps=0.0 q=-0.0 Lsize=N/A time=00:00:12.48 bitrate=N/A speed= 226x    ts/s speed=N/A
# video:425kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: unknown
# ffmpeg version 6.0 Copyright (c) 2000-2023 the FFmpeg developers
#   built with Apple clang version 15.0.0 (clang-1500.0.40.1)
#   configuration: --prefix=/opt/homebrew/Cellar/ffmpeg/6.0_1 --enable-shared --enable-pthreads --enable-version3 --cc=clang --host-cflags= --host-ldflags='-Wl,-ld_classic' --enable-ffplay --enable-gnutls --enable-gpl --enable-libaom --enable-libaribb24 --enable-libbluray --enable-libdav1d --enable-libjxl --enable-libmp3lame --enable-libopus --enable-librav1e --enable-librist --enable-librubberband --enable-libsnappy --enable-libsrt --enable-libsvtav1 --enable-libtesseract --enable-libtheora --enable-libvidstab --enable-libvmaf --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxml2 --enable-libxvid --enable-lzma --enable-libfontconfig --enable-libfreetype --enable-frei0r --enable-libass --enable-libopencore-amrnb --enable-libopencore-amrwb --enable-libopenjpeg --enable-libspeex --enable-libsoxr --enable-libzmq --enable-libzimg --disable-libjack --disable-indev=jack --enable-videotoolbox --enable-audiotoolbox --enable-neon
#   libavutil      58.  2.100 / 58.  2.100
#   libavcodec     60.  3.100 / 60.  3.100
#   libavformat    60.  3.100 / 60.  3.100
#   libavdevice    60.  1.100 / 60.  1.100
#   libavfilter     9.  3.100 /  9.  3.100
#   libswscale      7.  1.100 /  7.  1.100
#   libswresample   4. 10.100 /  4. 10.100
#   libpostproc    57.  1.100 / 57.  1.100
# -vsync is deprecated. Use -fps_mode
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from 'dataset_video/tiktok/9.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     comment         : vid:v09025g40000clorg8nog65ghqc0cun0
#     encoder         : Lavf58.76.100
#   Duration: 00:00:23.02, start: 0.000000, bitrate: 614 kb/s
#   Stream #0:0[0x1](und): Video: h264 (High) (avc1 / 0x31637661), yuv420p(progressive), 1024x576 [SAR 1:1 DAR 16:9], 577 kb/s, 25 fps, 25 tbr, 12800 tbn (default)
#     Metadata:
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
#   Stream #0:1[0x2](und): Audio: aac (HE-AACv2) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 32 kb/s (default)
#     Metadata:
#       handler_name    : SoundHandler
#       vendor_id       : [0][0][0][0]
# Stream mapping:
#   Stream #0:0 -> #0:0 (h264 (native) -> png (native))
# Press [q] to stop, [?] for help
# [swscaler @ 0x1303e0000] [swscaler @ 0x150158000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x1303e0000] [swscaler @ 0x150168000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x1303e0000] [swscaler @ 0x150178000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x1303e0000] [swscaler @ 0x150930000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x1303e0000] [swscaler @ 0x150940000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x1303e0000] [swscaler @ 0x150950000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x1303e0000] [swscaler @ 0x150960000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x1303e0000] [swscaler @ 0x1509a8000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x1303e0000] [swscaler @ 0x1509b8000] No accelerated colorspace conversion found from yuv420p to rgb24.
# Output #0, image2, to './Database_3D/dataset_test/tiktok/10/img_%05d.png':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     comment         : vid:v09025g40000clorg8nog65ghqc0cun0
#     encoder         : Lavf60.3.100
#   Stream #0:0(und): Video: png, rgb24(pc, gbr/unknown/unknown, progressive), 1024x576 [SAR 1:1 DAR 16:9], q=2-31, 200 kb/s, 25 fps, 25 tbn (default)
#     Metadata:
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
#       encoder         : Lavc60.3.100 png
# frame=    6 fps=0.0 q=-0.0 Lsize=N/A time=00:00:19.20 bitrate=N/A speed= 263x    ts/s speed=N/A
# video:1338kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: unknown
