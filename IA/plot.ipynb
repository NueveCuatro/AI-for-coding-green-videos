# %%
loss_saved=[0.05303764878772199, 0.06235471460968256, 0.0140811363235116, 0.02289538155309856, 0.023341138381510973, 0.011089835548773408, 0.01276141731068492, 0.011547699803486466, 0.010588551638647914, 0.010370013304054737, 0.010392284486442804, 0.010214383015409112, 0.009896333096548915, 0.009974271524697542, 0.009855997515842319, 0.00980707653798163, 0.009796321857720613, 0.009922117460519075, 0.009866970824077725, 0.009978798916563392, 0.009778449311852455, 0.009741416200995445, 0.01009394321590662, 0.009763444541022182, 0.009857576107606292, 0.009858226869255304, 0.009858643403276801, 0.009782507317140698, 0.009825876448303461, 0.00980955664999783]
import matplotlib.pyplot as plt

# Création de la courbe
plt.plot(loss_saved)

# Ajout de titres aux axes
plt.xlabel('Epochs')
plt.ylabel('Loss Value')

# Ajout d'un titre global
plt.title('Loss en fonction des epochs')

# Affichage de la courbe
plt.show()

# %%
loss_saved=[0.01089935633353889, 0.010588157456368208, 0.010781751945614815, 0.011750005418434739, 0.010544769233092666, 0.010808430844917893, 0.010864512994885445, 0.010486838407814503, 0.010711678070947528, 0.010740209836512804, 0.010007568635046482, 0.010055429069325328, 0.009943873155862093, 0.010147033957764506, 0.010009366786107421, 0.0100267066154629, 0.010139454854652286, 0.010222411481663585, 0.009957114467397332, 0.009959091898053885, 0.009955184999853373, 0.01003561750985682, 0.010178729426115751, 0.00994287128560245, 0.00965631753206253, 0.009808989241719246, 0.00979878450743854, 0.009748992044478655, 0.009789003757759929, 0.00975632737390697]
import matplotlib.pyplot as plt

# Création de la courbe
plt.plot(loss_saved)

# Ajout de titres aux axes
plt.xlabel('Epochs')
plt.ylabel('Loss Value')

# Ajout d'un titre global
plt.title('Loss en fonction des epochs')

# Affichage de la courbe
plt.show()

# %%
loss_saved=[0.011594010051339865, 0.010970479110255837, 0.010904021095484495, 0.010719566373154521, 0.010585242649540305, 0.01052221329882741, 0.010500581469386816, 0.010668183211237192, 0.010421541752293706, 0.010412722360342741, 0.010433047777041793, 0.010503966826945543, 0.010329201584681869, 0.010400662198662758, 0.010382808512076735, 0.010371761629357934, 0.010411534924060106, 0.01039835624396801, 0.01038161595351994, 0.010253837332129478, 0.010305328760296106, 0.01034723175689578, 0.010371839394792914, 0.010285608470439911, 0.010426324792206287, 0.010393145261332393, 0.010280495742335916, 0.010230332147330046, 0.010311682475730777, 0.010364388348534703]
import matplotlib.pyplot as plt

# Création de la courbe
plt.plot(loss_saved)

# Ajout de titres aux axes
plt.xlabel('Epochs')
plt.ylabel('Loss Value')

# Ajout d'un titre global
plt.title('Loss en fonction des epochs')

# Affichage de la courbe
plt.show()
